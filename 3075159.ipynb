# %% [markdown]
# # Midterm Project
#
# The midterm project is designed to let you apply what you have learned so far, and demonstrate that you have mastered it. The submission will be graded on the correctness of the execution of your analysis (50%), the ambitiousness of the problems chosen (30%), and the creativity of your questions and solutions (20%).
#
# Please note that the project is *individual*, and the solutions will be checked for substantial overlap. However, you should feel free to discuss problems and ideas with your class mates, just do not share code.
#
# Your submission should include all outputs and be self-contained, so it can be executed if necessary.
#
#
# ## Submission
# The project is due on March 29, 23:59 CET. Late submissions will not be considered, and graded as 0. To submit, please:
#
# 1. rename this file with your student ID
# 2. copy this file and all additional data into a folder with your student ID
# 3. zip the folder
# 4. upload to Blackboard and send a copy or link to a copy of the zip file to Tommaso Fornaciari <fornaciari@unibocconi.it>

# %% [markdown]
# ## Data and Preprocessing (5 pts)
#
# Pick a data set, either from the ones we have used in class, or one that you have found yourself (up to 2 bonus points, depending on size and complexity).
# Briefly (max. 100 words!) describe the content and type of the data set (book, reviews, Twitter, ...).
#
# Preprocess the data and explain (max. 200 words) which preprocessing steps you chose and why, and give statistics of the number of documents, types, and tokens, before and after preprocessing.

# %%
# merge the files in dataset into one txt file
import os
root='/Users/yeweiting/Downloads/aclImdb/train/unsup'
filelist=os.listdir('/Users/yeweiting/Downloads/aclImdb/train/unsup')
root1='/Users/yeweiting/Downloads/aclImdb/train/pos'
filelist1=os.listdir('/Users/yeweiting/Downloads/aclImdb/train/pos')
root2='/Users/yeweiting/Downloads/aclImdb/train/neg'
filelist2=os.listdir('/Users/yeweiting/Downloads/aclImdb/train/neg')

with open('unsup_file.txt','a+',encoding='utf-8') as newfile:
    for file in filelist:
        txt=open(os.path.join(root,file),encoding='utf-8')
        newfile.write(txt.read()+"\n")
newfile.close()

with open('pos_file.txt','a+',encoding='utf-8') as newfile:
    for file in filelist1:
        txt=open(os.path.join(root1,file),encoding='utf-8')
        newfile.write(txt.read()+"\n")
newfile.close()

with open('neg_file.txt','a+',encoding='utf-8') as newfile:
    for file in filelist2:
        txt=open(os.path.join(root2,file),encoding='utf-8')
        newfile.write(txt.read()+"\n")
newfile.close()

# %% [markdown]
# ##### Dataset Description:

# %% [markdown]
# Here I choose a dataset which contains movie reviews along with their associated binary sentiment polarity labels.
#
# The core dataset contains 50,000 reviews split evenly into 25k training and 25k test sets. The overall distribution of labels is balanced (25k pos and 25k neg). There are also additional 50,000 unlabeled documents for unsupervised learning.
#
# Here to accelerate the processing time, I concatunate the positive and negative reviews in the training set (25,000 in all) and decide to use their sentiment labels as the category in carrying out latent topics analysis.

# %%
#read the files of positive and negative reviews inspectively and export the files into a dataframe
import pandas as pd
pos_reviews = [line.strip() for line in open('/Users/yeweiting/Downloads/NLP/pos_file.txt', encoding='utf8')]
df_pos = pd.DataFrame(pos_reviews,columns=["review"])
df_pos['attitude']='positive'

# %%
neg_reviews = [line.strip() for line in open('/Users/yeweiting/Downloads/NLP/neg_file.txt', encoding='utf8')]
df_neg = pd.DataFrame(neg_reviews,columns=["review"])
df_neg['attitude']='negative'

# %%
# concatenate the reviews and also keep the attitude
df = pd.concat([df_pos,df_neg], axis=0, join='inner', ignore_index=True)
df.head()
# Out:
#                                               review  attitude
# 0  For a movie that gets no respect there sure ar...  positive
# 1  Bizarre horror movie filled with famous faces ...  positive
# 2  A solid, if unremarkable film. Matthau, as Ein...  positive
# 3  It's a strange feeling to sit alone in a theat...  positive
# 4  You probably all already know this by now, but...  positive

# %%
df.tail()
# Out:
#                                                   review  attitude
# 24995  My comments may be a bit of a spoiler, for wha...  negative
# 24996  The "saucy" misadventures of four au pairs who...  negative
# 24997  Oh, those Italians! Assuming that movies about...  negative
# 24998  Eight academy nominations? It's beyond belief....  negative
# 24999  Not that I dislike childrens movies, but this ...  negative

# %%
df.shape
# Out:
# (25000, 2)

# %%
#count the number of tokens
import spacy

nlp = spacy.load('en', disable=['tagger', 'parser', 'ner'])

documents = df.review.apply(str).tolist()
tokens = [token.text for sentence in documents[:25000] for token in nlp(sentence)]
len(tokens)
# Out:
# 6810246

# %%
import nltk
import matplotlib.pyplot as plt
freq = nltk.FreqDist(tokens)

# %%
freq.plot(30, cumulative=False)

# %% [markdown]
# ##### Before preprocessing the data, we have 25000 documents with 6810246 tokens including duplicate words.
# And from the plotting of the token frequency, we see that there are many meaningless punctuations and prepositions.
#
# Now we apply data cleaning.
#
# We should get rid of the stopwords, punctuations, digits, and both the most and the least frequent 40 words.

# %%
# count the number of words in each document
df['word_count']=df['review'].apply(lambda x:len(str(x).split(" ")))
# count the number of characters in each document
df['char_count']=df['review'].str.len()

# delete the stopwords
from nltk.corpus import stopwords
stop=stopwords.words('english')
df['stopwords']=df['review'].apply(lambda sen:len([x for x in sen.split() if x in stop]))
df['review']=df['review'].apply(lambda sen:" ".join(x for x in sen.split() if x not in stop))

# transform into lower-case and delete the punctuations and digits in each document
df['review']=df['review'].apply(lambda sen:" ".join(x.lower() for x in sen.split()))
df['review'] = df['review'].str.replace('[^\w\s]','')
df['review']=df['review'].apply(lambda sen:" ".join(x for x in sen.split() if not x.isdigit()))

# calculate the average length of word in each document
def avg_word(sentence):
    words=sentence.split()
    return (sum(len(word) for word in words)/len(words))

df['avg_word']=df['review'].apply(lambda x:avg_word(x))

# %%
df.head()
# Out:
#                                               review  attitude  word_count  \
# 0  for movie gets respect sure lot memorable quot...  positive          52
# 1  bizarre horror movie filled famous faces stole...  positive         166
# 2  a solid unremarkable film matthau einstein won...  positive          55
# 3  its strange feeling sit alone theater occupied...  positive         442
# 4  you probably already know now additional episo...  positive         144
#
#    char_count  stopwords  avg_word
# 0         284         19  5.424242
# 1        1033         57  6.443396
# 2         318         25  6.000000
# 3        2596        163  5.716364
# 4         783         59  5.268293

# %% [markdown]
# According to the zipf distribution of words, the most frequent words would far surpass the others in terms of word frequency. Meanwhile, these usually are useless words that contain no sentimental tendency. So, we'd better get rid of them.

# %%
most_freq=pd.Series(' '.join(df['review']).split()).value_counts()[:50].index.tolist()
df['review']=df['review'].apply(lambda sen:' '.join(x for x in sen.split() if x not in most_freq))

# %% [markdown]
# The least frequent words may be proper nouns, entity names or words derived from other languages. They are not of much value to our analysis. We should get rid of them as well.

# %%
least_freq = pd.Series(' '.join(df['review']).split()).value_counts()[-10:].index.tolist()
df['review'] = df['review'].apply(lambda x: " ".join(x for x in x.split() if x not in least_freq))

# %% [markdown]
# By now, we have performed a brief cleaning of the data. Let's see how it turns out to be.

# %%
documents = df.review.apply(str).tolist()
print(documents[1])
# Out:
# bizarre horror filled famous faces stolen cristina raines later tvs flamingo road pretty somewhat unstable model gummy smile slated pay attempted suicides guarding gateway hell scenes raines modeling captured mood music perfect deborah raffin charming cristinas pal raines moves creepy brooklyn heights brownstone inhabited blind priest top floor things start cooking neighbors including fantastically wicked burgess meredith kinky couple sylvia miles beverly dangelo diabolical lot eli wallach fun wily police detective nearly crosspollination rosemarys baby exorcistbut combination based bestseller jeffrey konvitz sentinel entertainingly spooky full shocks brought director michael winner mounts thoughtfully downbeat ending skill

# %%
tokens = [token.text for sentence in documents[:25000] for token in nlp(sentence)]
len(tokens)
# Out:
# 2747721

# %%
freq2 = nltk.FreqDist(tokens)
freq2.plot(30, cumulative=False)

# %% [markdown]
# ##### The distribution seems more balanced now in terms of the diminished differences in y-axis "Counts".

# %% [markdown]
# ##### After preprocessing the data, we now have 25000 documents with 2747721 tokens including duplicate words.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(analyzer='word', min_df=0.001, max_df=0.75, stop_words='english', sublinear_tf=True)

X = tfidf_vectorizer.fit_transform(documents)

# %%
X.shape # indicating 25000 documents with 10144 features
# Out:
# (25000, 10144)

# %% [markdown]
# ##### After preprocessing the data, we now have 25000 documents with 10144 unique features.

# %% [markdown]
# ## Analysis (16 pts)
#
# Describe what you are investigating with the data (max. 100 words, 3 pts), and apply at least one version of *each* of the following analysis methods to the data set (justify your choices):
# 1. TFIDF analysis of important terms **or** latent topics from matrix factorization (2 pts)
# 2. Topic modeling with LDA (4 pts)
# 3. Dense word or document embeddings (4 pts)
# 4. Clustering (3 pts)
#
# If appropriate for your probelm, feel free to explore other methods we discussed (NER, parsing, POS, etc.), or algorithms not covered in class (e.g., clustering algorithms, etc.), as long as they do not require additional libraries (up to 2 bonus points).

# %% [markdown]
# ### Objective

# %% [markdown]
# By analyzing the concatunated movie reviews, I would like to investigate what indicators of a movie are important to the audience. These crucial indicators would largely lead to viewers' sentimental fluctuations.
#
# Derived from the main goal, we can also learn the commenting patterns of the audience, such as what kind of words they use most commonly.

# %% [markdown]
# ### TFIDF analysis of important terms

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer='word', min_df=0.001, max_df=0.75, stop_words='english')

X2 = vectorizer.fit_transform(documents)

# %%
# indicating 25000 documents with 10144 features
X.shape, X2.shape
# Out:
# ((25000, 10144), (25000, 10144))

# %%
word_counts = X2.toarray()
word_tfidf = X.toarray()
word_tfidf[word_tfidf < 0.2] = 0

df2 = pd.DataFrame(data={'word': vectorizer.get_feature_names(), 
                        'tf': word_counts.sum(axis=0), 
                        'idf': tfidf_vectorizer.idf_,
                        'tfidf': word_tfidf.sum(axis=0)
                       })

# %%
df2 = df2.sort_values(['tfidf','tf','idf']) #ascending in order of 'tfidf', 'tf', 'idf'
df2.tail()
# Out:
#            word    tf       idf      tfidf
# 1543  christmas   598  5.330613  22.714471
# 2603     disney   640  5.226774  24.509568
# 8028     series  3198  3.621729  24.935303
# 3070    episode  1593  4.256618  25.524590
# 1002       book  2271  3.908494  34.465585

# %% [markdown]
# ### Latent topics from matrix factorization

# %%
from sklearn.decomposition import NMF

k = 10
nmf = NMF(n_components=k, init='nndsvd', random_state=0)  ##Nonnegative Double Singular Value Decomposition

# %time W = nmf.fit_transform(X)
H = nmf.components_
# Out:
# CPU times: user 19.6 s, sys: 535 ms, total: 20.2 s
# Wall time: 11 s

# %%
W.shape, H.shape
# Out:
# ((25000, 10), (10, 10144))

# %%
import numpy as np
def show_topics(a, vocabulary, topn=10):
    """
    find the top N words for each of the latent dimensions (=rows) in a
    """
    topic_words = ([[vocabulary[i] for i in np.argsort(t)[:-topn-1:-1]]
                    for t in a])
    return [', '.join(t) for t in topic_words]

# %%
terms = tfidf_vectorizer.get_feature_names()
sorted(show_topics(H, terms))
# Out:
# ['cast, role, performance, actors, excellent, actor, performances, john, play, played',
#  'funny, comedy, laugh, jokes, humor, hilarious, fun, funniest, laughs, comedies',
#  'horror, effects, special, gore, budget, scary, blood, low, zombie, killer',
#  'im, say, thought, going, ive, thats, watching, sure, better, got',
#  'life, world, real, war, work, human, true, documentary, american, history',
#  'man, gets, girl, woman, guy, young, goes, father, wife, hes',
#  'saw, years, old, kids, remember, dvd, ago, loved, music, year',
#  'scenes, action, scene, fight, interesting, pretty, lot, bit, quite, better',
#  'series, episode, episodes, tv, season, shows, original, new, television, trek',
#  'worst, waste, money, awful, terrible, actors, script, horrible, worse, dont']

# %% [markdown]
# ##### As inferred from the shown topics, 10 latent topics may be concluded as:
# - actors'/actresses' performance
# - comedies
# - horror films
# - general comments
# - documentary films
# - love films
# - family films
# - action films
# - tv series
# - extremely bad reviews

# %% [markdown]
# ### Topic modeling with LDA

# %%
from gensim.models import LdaMulticore, TfidfModel
from gensim.corpora import Dictionary
import time # to know how long training took
import multiprocessing # to speed things up by parallelizing

# %%
# get dictionary
instances = df.review.apply(str.split)[:25000] #str.split creates a list of each single word
print("creating dictionary", flush=True)  # file = 'stderr' 'standard error' or 'standard out'
# read in instances and create Dictionary object w information about frequencies etc. 
dictionary = Dictionary(instances)
# get rid of words that are too rare or too frequent
dictionary.filter_extremes(no_below=100, no_above=0.1)
print(dictionary, flush=True)
# Out:
# creating dictionary
# Dictionary(3602 unique tokens: ['absolute', 'alan', 'gem', 'imagine', 'joe']...)

# %%
#replace words by their numerical IDs and their frequency
print("translating corpus to IDs", flush=True)
ldacorpus = [dictionary.doc2bow(text) for text in instances]
# learn TFIDF values from corpus
print("tf-idf transformation", flush=True)
tfidfmodel = TfidfModel(ldacorpus)
# transform raw frequencies into TFIDF
model_corpus = tfidfmodel[ldacorpus]

num_topics = 10 

# find chunksize to make about 200 updates
num_passes = 10
chunk_size = len(model_corpus) * num_passes/200
print(chunk_size)

start = time.time()
print("fitting model", flush=True)
model = LdaMulticore(model_corpus, # what to train on
                     num_topics=num_topics, # number of topics
                     id2word=dictionary, # mappinf from IDs to words
                     workers=min(10, multiprocessing.cpu_count()-1), # choose 10 cores, or whatever computer has
                     passes=num_passes, # make this many passes over data
                     chunksize=chunk_size # update after this many instances
                     # alpha = 0.0001 change the peakness
                    )
    
print("done in {}".format(time.time()-start), flush=True)
# Out:
# translating corpus to IDs
# tf-idf transformation
# 1250.0
# fitting model
# done in 188.93588709831238

# %%
import re

# transform the data into topic distros
topic_corpus = model[model_corpus]

# get the topic descritions
topic_sep = re.compile(r"0\.[0-9]{3}\*") # getting rid of useless formatting
# extract a list of tuples with topic number and descriptors from the model
model_topics = [(topic_no, re.sub(topic_sep, '', model_topic).split(' + ')) for topic_no, model_topic in
                model.print_topics(num_topics=num_topics, num_words=5)]

descriptors = []
for i, m in model_topics:
    print(i+1, ", ".join(m[:5]))
    descriptors.append(", ".join(m[:2]).replace('"', ''))
# Out:
# 1 "freddy", "murphy", "eddie", "don", "joe"
# 2 "jesus", "eddie", "murphy", "raw", "professional"
# 3 "horror", "worst", "waste", "terrible", "boring"
# 4 "hitler", "germany", "german", "documentary", "nancy"
# 5 "worst", "stupid", "jokes", "kids", "comedy"
# 6 "stanley", "inspiring", "scenery", "painting", "aliens"
# 7 "bugs", "deeper", "cartoons", "disappointed", "relationship"
# 8 "christmas", "santa", "woody", "allen", "holiday"
# 9 "season", "trek", "episodes", "episode", "book"
# 10 "role", "performance", "family", "music", "she"

# %% [markdown]
# ### Dense word or document embeddings

# %% [markdown]
# #### Word embedding with Word2Vec

# %% [markdown]
# ##### Because of the high dimensions of the corpus, here I seperate the data and process the word embedding seperatively according to different attitudes.

# %%
df_pos = df[:12500]
df_neg = df[12500:]

# %%
def build_corpus(data):
    "Creates a list of lists containing words from each sentence/document"
    corpus = []
    for col in ['review']:
        for sentence in data[col].iteritems():
            word_list = sentence[1].split(" ")
            corpus.append(word_list)
            
    return corpus

# %%
corpus_pos = build_corpus(df_pos) 
corpus_neg = build_corpus(df_neg)
corpus_all = build_corpus(df)

# %%
from gensim.models import word2vec

# to accelerate the processing time, here I set the number of dimensions to 100 (size=100)
# and to create a more selective model, the minimum counts of times are set to 500
model_pos = word2vec.Word2Vec(corpus_pos, size=100, window=20, min_count=500, workers=4)
model_neg = word2vec.Word2Vec(corpus_neg, size=100, window=20, min_count=500, workers=4)
model_all = word2vec.Word2Vec(corpus_all, size=100, window=20, min_count=500, workers=4)

# %%
model_neg.wv['horror'] # take the word "horror" for example, let's see how its vector looks like
# Out:
# array([-0.8025961 ,  0.41894802,  2.4200501 , -0.81215096,  0.46707684,
#        -0.8956733 ,  2.702691  , -0.45315924, -0.91088307,  0.8790514 ,
#        -0.84015346, -0.20069125, -0.6158845 ,  1.3497803 ,  0.61076045,
#        -0.46413407,  0.06593391, -0.1285677 , -0.29938057, -1.9687024 ,
#        -2.1505032 ,  0.18090807,  1.3530598 ,  0.49541146,  0.8193175 ,
#        -1.7773843 ,  0.5926681 , -1.5270045 , -2.043757  ,  0.56386805,
#        -1.2443035 , -1.5737085 ,  2.4628284 , -1.3981127 , -0.8824293 ,
#        -0.04610708, -1.2495892 , -0.3485486 , -1.6704755 ,  0.8424174 ,
#         0.45235944, -1.7746688 ,  2.4046097 , -0.7509302 , -2.109868  ,
#         0.6270152 ,  0.4541923 ,  0.5538928 ,  0.79105556, -0.6447781 ,
#         0.9102759 ,  1.1400145 ,  1.9727614 , -0.13225253, -0.61830544,
#        -0.06114746,  0.04556177, -0.29186398,  0.93092364, -0.72158486,
#        -0.27188405, -1.4083569 ,  0.5403807 ,  2.9122612 ,  1.0861577 ,
#         0.29055142, -0.50769895,  0.15933906, -1.862343  ,  0.6713279 ,
#         1.5122192 , -2.184124  , -0.71374786, -1.0369803 ,  1.3342785 ,
#         0.292138  ,  1.226792  ,  0.19849372,  0.20278998, -0.8441706 ,
#         1.6045516 ,  0.926431  ,  0.32652825,  1.3030168 ,  0.9889724 ,
#         0.3273197 , -0.23273927, -0.88880676,  1.2673049 , -0.9334551 ,
#         0.07506728,  2.0337813 , -0.5412983 , -0.27013326, -0.7691736 ,
#         1.6802711 , -0.42226663,  0.2808901 ,  1.3263721 , -0.8862936 ],
#       dtype=float32)

# %%
print("Shape of model_pos: {}".format(model_pos.wv.vectors.shape))
print("Shape of model_neg: {}".format(model_neg.wv.vectors.shape))
print("Shape of model_all: {}".format(model_all.wv.vectors.shape))
# Out:
# Shape of model_pos: (473, 100)
# Shape of model_neg: (483, 100)
# Shape of model_all: (1004, 100)

# %%
model_all.wv.index2word[:10]
# Out:
# ['life', 'show', 'ever', 'if', 'still', 'better', 'end', 'say', 'man', 'scene']

# %% [markdown]
# #### Document embedding with Doc2Vec

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import FAST_VERSION
from gensim.models.doc2vec import TaggedDocument
from gensim.models.doc2vec import Doc2Vec,LabeledSentence


corpus2 = []
for docid, document in enumerate(documents):
    corpus2.append(TaggedDocument(document.split(), tags=["{}".format(docid)]))

print('done')
d2v_model = Doc2Vec(vector_size=100, 
                    window=15,
                    hs=0,
                    sample=0.000001,
                    negative=5,
                    min_count=100,
                    workers=-1,
                    epochs=500,
                    dm=0,  
                    dbow_words=1) #whether or not to train the words

d2v_model.build_vocab(corpus2)

d2v_model.train(corpus2, total_examples=d2v_model.corpus_count, epochs=d2v_model.epochs)
# Out:
# done

# %%
d2v_model.docvecs.doctags
# Out:
# {'0': Doctag(offset=0, word_count=27, doc_count=1),
#  '1': Doctag(offset=1, word_count=95, doc_count=1),
#  '2': Doctag(offset=2, word_count=23, doc_count=1),
#  '3': Doctag(offset=3, word_count=233, doc_count=1),
#  '4': Doctag(offset=4, word_count=69, doc_count=1),
#  '5': Doctag(offset=5, word_count=38, doc_count=1),
#  '6': Doctag(offset=6, word_count=53, doc_count=1),
#  '7': Doctag(offset=7, word_count=43, doc_count=1),
#  '8': Doctag(offset=8, word_count=260, doc_count=1),
#  '9': Doctag(offset=9, word_count=24, doc_count=1),
#  '10': Doctag(offset=10, word_count=26, doc_count=1),
#  '11': Doctag(offset=11, word_count=241, doc_count=1),
#  '12': Doctag(offset=12, word_count=27, doc_count=1),
#  '13': Doctag(offset=13, word_count=291, doc_count=1),
#  '14': Doctag(offset=14, word_count=63, doc_count=1),
#  '15': Doctag(offset=15, word_count=23, doc_count=1),
#  '16': Doctag(offset=16, word_count=52, doc_count=1),
#  '17': Doctag(offset=17, word_count=78, doc_count=1),
#  '18': Doctag(offset=18, word_count=70, doc_count=1),
#  '19': Doctag(offset=19, word_count=51, doc_count=1),
#  '20': Doctag(offset=20, word_count=38, doc_count=1),
#  '21': Doctag(offset=21, word_count=52, doc_count=1),
#  '22': Doctag(offset=22, word_count=345, doc_count=1),
#  '23': Doctag(offset=23, word_count=51, doc_count=1),
#  '24': Doctag(offset=24, word_count=91, doc_count=1),
#  '25': Doctag(offset=25, word_count=122, doc_count=1),
#  '26': Doctag(offset=26, word_count=73, doc_count=1),
#  '27': Doctag(offset=27, word_count=236, doc_count=1),
#  '28': Doctag(offset=28, word_count=50, doc_count=1),
#  '29': Doctag(offset=29, word_count=128, doc_count=1),
#  '30': Doctag(offset=30, word_count=245, doc_count=1),
#  '31': Doctag(offset=31, word_count=79, doc_count=1),
#  '32': Doctag(offset=32, word_count=80, doc_count=1),
#  '33': Doctag(offset=33, word_count=100, doc_count=1),
#  '34': Doctag(offset=34, word_count=65, doc_count=1),
#  '35': Doctag(offset=35, word_count=50, doc_count=1),
#  '36': Doctag(offset=36, word_count=72, doc_count=1),
#  '37': Doctag(offset=37, word_count=36, doc_count=1),
#  '38': Doctag(offset=38, word_count=42, doc_count=1),
#  '39': Doctag(offset=39, word_count=121, doc_count=1),
#  '40': Doctag(offset=40, word_count=53, doc_count=1),
#  '41': Doctag(offset=41, word_count=39, doc_count=1),
#  '42': Doctag(offset=42, word_count=215, doc_count=1),
#  '43': Doctag(offset=43, word_count=164, doc_count=1),
#  '44': Doctag(offset=44, word_count=70, doc_count=1),
#  '45': Doctag(offset=45, word_count=68, doc_count=1),
#  '46': Doctag(offset=46, word_count=73, doc_count=1),
#  '47': Doctag(offset=47, word_count=56, doc_count=1),
#  '48': Doctag(offset=48, word_count=22, doc_count=1),
#  '49': Doctag(offset=49, word_count=135, doc_count=1),
#  '50': Doctag(offset=50, word_count=75, doc_count=1),
#  '51': Doctag(offset=51, word_count=122, doc_count=1),
#  '52': Doctag(offset=52, word_count=53, doc_count=1),
#  '53': Doctag(offset=53, word_count=66, doc_count=1),
#  '54': Doctag(offset=54, word_count=73, doc_count=1),
#  '55': Doctag(offset=55, word_count=338, doc_count=1),
#  '56': Doctag(offset=56, word_count=69, doc_count=1),
#  '57': Doctag(offset=57, word_count=250, doc_count=1),
#  '58': Doctag(offset=58, word_count=282, doc_count=1),
#  '59': Doctag(offset=59, word_count=196, doc_count=1),
#  '60': Doctag(offset=60, word_count=51, doc_count=1),
#  '61': Doctag(offset=61, word_count=87, doc_count=1),
#  '62': Doctag(offset=62, word_count=53, doc_count=1),
#  '63': Doctag(offset=63, word_count=60, doc_count=1),
#  '64': Doctag(offset=64, word_count=68, doc_count=1),
#  '65': Doctag(offset=65, word_count=108, doc_count=1),
#  '66': Doctag(offset=66, word_count=39, doc_count=1),
#  '67': Doctag(offset=67, word_count=111, doc_count=1),
#  '68': Doctag(offset=68, word_count=77, doc_count=1),
#  '69': Doctag(offset=69, word_count=259, doc_count=1),
#  '70': Doctag(offset=70, word_count=34, doc_count=1),
#  '71': Doctag(offset=71, word_count=69, doc_count=1),
#  '72': Doctag(offset=72, word_count=36, doc_count=1),
#  '73': Doctag(offset=73, word_count=66, doc_count=1),
#  '74': Doctag(offset=74, word_count=43, doc_count=1),
#  '75': Doctag(offset=75, word_count=152, doc_count=1),
#  '76': Doctag(offset=76, word_count=102, doc_count=1),
#  '77': Doctag(offset=77, word_count=62, doc_count=1),
#  '78': Doctag(offset=78, word_count=56, doc_count=1),
#  '79': Doctag(offset=79, word_count=123, doc_count=1),
#  '80': Doctag(offset=80, word_count=140, doc_count=1),
#  '81': Doctag(offset=81, word_count=138, doc_count=1),
#  '82': Doctag(offset=82, word_count=98, doc_count=1),
#  '83': Doctag(offset=83, word_count=54, doc_count=1),
#  '84': Doctag(offset=84, word_count=144, doc_count=1),
#  '85': Doctag(offset=85, word_count=58, doc_count=1),
#  '86': Doctag(offset=86, word_count=50, doc_count=1),
#  '87': Doctag(offset=87, word_count=164, doc_count=1),
#  '88': Doctag(offset=88, word_count=231, doc_count=1),
#  '89': Doctag(offset=89, word_count=63, doc_count=1),
#  '90': Doctag(offset=90, word_count=69, doc_count=1),
#  '91': Doctag(offset=91, word_count=74, doc_count=1),
#  '92': Doctag(offset=92, word_count=38, doc_count=1),
#  '93': Doctag(offset=93, word_count=105, doc_count=1),
#  '94': Doctag(offset=94, word_count=61, doc_count=1),
#  '95': Doctag(offset=95, word_count=50, doc_count=1),
#  '96': Doctag(offset=96, word_count=68, doc_count=1),
#  '97': Doctag(offset=97, word_count=189, doc_count=1),
#  '98': Doctag(offset=98, word_count=50, doc_count=1),
#  '99': Doctag(offset=99, word_count=56, doc_count=1),
#  '100': Doctag(offset=100, word_count=55, doc_count=1),
#  '101': Doctag(offset=101, word_count=21, doc_count=1),
#  '102': Doctag(offset=102, word_count=112, doc_count=1),
#  '103': Doctag(offset=103, word_count=32, doc_count=1),
#  '104': Doctag(offset=104, word_count=61, doc_count=1),
#  '105': Doctag(offset=105, word_count=174, doc_count=1),
#  '106': Doctag(offset=106, word_count=264, doc_count=1),
#  '107': Doctag(offset=107, word_count=263, doc_count=1),
#  '108': Doctag(offset=108, word_count=110, doc_count=1),
#  '109': Doctag(offset=109, word_count=68, doc_count=1),
#  '110': Doctag(offset=110, word_count=52, doc_count=1),
#  '111': Doctag(offset=111, word_count=62, doc_count=1),
#  '112': Doctag(offset=112, word_count=135, doc_count=1),
#  '113': Doctag(offset=113, word_count=83, doc_count=1),
#  '114': Doctag(offset=114, word_count=176, doc_count=1),
#  '115': Doctag(offset=115, word_count=194, doc_count=1),
#  '116': Doctag(offset=116, word_count=31, doc_count=1),
#  '117': Doctag(offset=117, word_count=15, doc_count=1),
#  '118': Doctag(offset=118, word_count=46, doc_count=1),
#  '119': Doctag(offset=119, word_count=235, doc_count=1),
#  '120': Doctag(offset=120, word_count=91, doc_count=1),
#  '121': Doctag(offset=121, word_count=206, doc_count=1),
#  '122': Doctag(offset=122, word_count=191, doc_count=1),
#  '123': Doctag(offset=123, word_count=73, doc_count=1),
#  '124': Doctag(offset=124, word_count=13, doc_count=1),
#  '125': Doctag(offset=125, word_count=40, doc_count=1),
#  '126': Doctag(offset=126, word_count=77, doc_count=1),
#  '127': Doctag(offset=127, word_count=87, doc_count=1),
#  '128': Doctag(offset=128, word_count=206, doc_count=1),
#  '129': Doctag(offset=129, word_count=143, doc_count=1),
#  '130': Doctag(offset=130, word_count=82, doc_count=1),
#  '131': Doctag(offset=131, word_count=147, doc_count=1),
#  '132': Doctag(offset=132, word_count=60, doc_count=1),
#  '133': Doctag(offset=133, word_count=278, doc_count=1),
#  '134': Doctag(offset=134, word_count=120, doc_count=1),
#  '135': Doctag(offset=135, word_count=108, doc_count=1),
#  '136': Doctag(offset=136, word_count=100, doc_count=1),
#  '137': Doctag(offset=137, word_count=23, doc_count=1),
#  '138': Doctag(offset=138, word_count=27, doc_count=1),
#  '139': Doctag(offset=139, word_count=188, doc_count=1),
#  '140': Doctag(offset=140, word_count=117, doc_count=1),
#  '141': Doctag(offset=141, word_count=260, doc_count=1),
#  '142': Doctag(offset=142, word_count=119, doc_count=1),
#  '143': Doctag(offset=143, word_count=64, doc_count=1),
#  '144': Doctag(offset=144, word_count=58, doc_count=1),
#  '145': Doctag(offset=145, word_count=90, doc_count=1),
#  '146': Doctag(offset=146, word_count=49, doc_count=1),
#  '147': Doctag(offset=147, word_count=203, doc_count=1),
#  '148': Doctag(offset=148, word_count=95, doc_count=1),
#  '149': Doctag(offset=149, word_count=28, doc_count=1),
#  '150': Doctag(offset=150, word_count=282, doc_count=1),
#  '151': Doctag(offset=151, word_count=94, doc_count=1),
#  '152': Doctag(offset=152, word_count=68, doc_count=1),
#  '153': Doctag(offset=153, word_count=67, doc_count=1),
#  '154': Doctag(offset=154, word_count=161, doc_count=1),
#  '155': Doctag(offset=155, word_count=121, doc_count=1),
#  '156': Doctag(offset=156, word_count=167, doc_count=1),
#  '157': Doctag(offset=157, word_count=15, doc_count=1),
#  '158': Doctag(offset=158, word_count=70, doc_count=1),
#  '159': Doctag(offset=159, word_count=10, doc_count=1),
#  '160': Doctag(offset=160, word_count=54, doc_count=1),
#  '161': Doctag(offset=161, word_count=120, doc_count=1),
#  '162': Doctag(offset=162, word_count=47, doc_count=1),
#  '163': Doctag(offset=163, word_count=115, doc_count=1),
#  '164': Doctag(offset=164, word_count=30, doc_count=1),
#  '165': Doctag(offset=165, word_count=254, doc_count=1),
#  '166': Doctag(offset=166, word_count=130, doc_count=1),
#  '167': Doctag(offset=167, word_count=56, doc_count=1),
#  '168': Doctag(offset=168, word_count=39, doc_count=1),
#  '169': Doctag(offset=169, word_count=271, doc_count=1),
#  '170': Doctag(offset=170, word_count=138, doc_count=1),
#  '171': Doctag(offset=171, word_count=70, doc_count=1),
#  '172': Doctag(offset=172, word_count=89, doc_count=1),
#  '173': Doctag(offset=173, word_count=92, doc_count=1),
#  '174': Doctag(offset=174, word_count=60, doc_count=1),
#  '175': Doctag(offset=175, word_count=29, doc_count=1),
#  '176': Doctag(offset=176, word_count=233, doc_count=1),
#  '177': Doctag(offset=177, word_count=103, doc_count=1),
#  '178': Doctag(offset=178, word_count=240, doc_count=1),
#  '179': Doctag(offset=179, word_count=275, doc_count=1),
#  '180': Doctag(offset=180, word_count=141, doc_count=1),
#  '181': Doctag(offset=181, word_count=75, doc_count=1),
#  '182': Doctag(offset=182, word_count=19, doc_count=1),
#  '183': Doctag(offset=183, word_count=36, doc_count=1),
#  '184': Doctag(offset=184, word_count=67, doc_count=1),
#  '185': Doctag(offset=185, word_count=167, doc_count=1),
#  '186': Doctag(offset=186, word_count=156, doc_count=1),
#  '187': Doctag(offset=187, word_count=99, doc_count=1),
#  '188': Doctag(offset=188, word_count=154, doc_count=1),
#  '189': Doctag(offset=189, word_count=116, doc_count=1),
#  '190': Doctag(offset=190, word_count=66, doc_count=1),
#  '191': Doctag(offset=191, word_count=381, doc_count=1),
#  '192': Doctag(offset=192, word_count=131, doc_count=1),
#  '193': Doctag(offset=193, word_count=61, doc_count=1),
#  '194': Doctag(offset=194, word_count=204, doc_count=1),
#  '195': Doctag(offset=195, word_count=45, doc_count=1),
#  '196': Doctag(offset=196, word_count=94, doc_count=1),
#  '197': Doctag(offset=197, word_count=105, doc_count=1),
#  '198': Doctag(offset=198, word_count=64, doc_count=1),
#  '199': Doctag(offset=199, word_count=152, doc_count=1),
#  '200': Doctag(offset=200, word_count=58, doc_count=1),
#  '201': Doctag(offset=201, word_count=39, doc_count=1),
#  '202': Doctag(offset=202, word_count=301, doc_count=1),
#  '203': Doctag(offset=203, word_count=186, doc_count=1),
#  '204': Doctag(offset=204, word_count=47, doc_count=1),
#  '205': Doctag(offset=205, word_count=67, doc_count=1),
#  '206': Doctag(offset=206, word_count=193, doc_count=1),
#  '207': Doctag(offset=207, word_count=199, doc_count=1),
#  '208': Doctag(offset=208, word_count=140, doc_count=1),
#  '209': Doctag(offset=209, word_count=61, doc_count=1),
#  '210': Doctag(offset=210, word_count=124, doc_count=1),
#  '211': Doctag(offset=211, word_count=125, doc_count=1),
#  '212': Doctag(offset=212, word_count=420, doc_count=1),
#  '213': Doctag(offset=213, word_count=100, doc_count=1),
#  '214': Doctag(offset=214, word_count=111, doc_count=1),
#  '215': Doctag(offset=215, word_count=150, doc_count=1),
#  '216': Doctag(offset=216, word_count=76, doc_count=1),
#  '217': Doctag(offset=217, word_count=60, doc_count=1),
#  '218': Doctag(offset=218, word_count=42, doc_count=1),
#  '219': Doctag(offset=219, word_count=107, doc_count=1),
#  '220': Doctag(offset=220, word_count=102, doc_count=1),
#  '221': Doctag(offset=221, word_count=217, doc_count=1),
#  '222': Doctag(offset=222, word_count=105, doc_count=1),
#  '223': Doctag(offset=223, word_count=76, doc_count=1),
#  '224': Doctag(offset=224, word_count=134, doc_count=1),
#  '225': Doctag(offset=225, word_count=61, doc_count=1),
#  '226': Doctag(offset=226, word_count=54, doc_count=1),
#  '227': Doctag(offset=227, word_count=63, doc_count=1),
#  '228': Doctag(offset=228, word_count=155, doc_count=1),
#  '229': Doctag(offset=229, word_count=269, doc_count=1),
#  '230': Doctag(offset=230, word_count=58, doc_count=1),
#  '231': Doctag(offset=231, word_count=52, doc_count=1),
#  '232': Doctag(offset=232, word_count=51, doc_count=1),
#  '233': Doctag(offset=233, word_count=50, doc_count=1),
#  '234': Doctag(offset=234, word_count=272, doc_count=1),
#  '235': Doctag(offset=235, word_count=51, doc_count=1),
#  '236': Doctag(offset=236, word_count=196, doc_count=1),
#  '237': Doctag(offset=237, word_count=139, doc_count=1),
#  '238': Doctag(offset=238, word_count=61, doc_count=1),
#  '239': Doctag(offset=239, word_count=148, doc_count=1),
#  '240': Doctag(offset=240, word_count=40, doc_count=1),
#  '241': Doctag(offset=241, word_count=143, doc_count=1),
#  '242': Doctag(offset=242, word_count=57, doc_count=1),
#  '243': Doctag(offset=243, word_count=66, doc_count=1),
#  '244': Doctag(offset=244, word_count=50, doc_count=1),
#  '245': Doctag(offset=245, word_count=274, doc_count=1),
#  '246': Doctag(offset=246, word_count=72, doc_count=1),
#  '247': Doctag(offset=247, word_count=173, doc_count=1),
#  '248': Doctag(offset=248, word_count=206, doc_count=1),
#  '249': Doctag(offset=249, word_count=202, doc_count=1),
#  '250': Doctag(offset=250, word_count=51, doc_count=1),
#  '251': Doctag(offset=251, word_count=202, doc_count=1),
#  '252': Doctag(offset=252, word_count=55, doc_count=1),
#  '253': Doctag(offset=253, word_count=188, doc_count=1),
#  '254': Doctag(offset=254, word_count=51, doc_count=1),
#  '255': Doctag(offset=255, word_count=57, doc_count=1),
#  '256': Doctag(offset=256, word_count=120, doc_count=1),
#  '257': Doctag(offset=257, word_count=95, doc_count=1),
#  '258': Doctag(offset=258, word_count=128, doc_count=1),
#  '259': Doctag(offset=259, word_count=112, doc_count=1),
#  '260': Doctag(offset=260, word_count=65, doc_count=1),
#  '261': Doctag(offset=261, word_count=230, doc_count=1),
#  '262': Doctag(offset=262, word_count=44, doc_count=1),
#  '263': Doctag(offset=263, word_count=73, doc_count=1),
#  '264': Doctag(offset=264, word_count=16, doc_count=1),
#  '265': Doctag(offset=265, word_count=13, doc_count=1),
#  '266': Doctag(offset=266, word_count=64, doc_count=1),
#  '267': Doctag(offset=267, word_count=101, doc_count=1),
#  '268': Doctag(offset=268, word_count=241, doc_count=1),
#  '269': Doctag(offset=269, word_count=140, doc_count=1),
#  '270': Doctag(offset=270, word_count=108, doc_count=1),
#  '271': Doctag(offset=271, word_count=131, doc_count=1),
#  '272': Doctag(offset=272, word_count=44, doc_count=1),
#  '273': Doctag(offset=273, word_count=100, doc_count=1),
#  '274': Doctag(offset=274, word_count=74, doc_count=1),
#  '275': Doctag(offset=275, word_count=288, doc_count=1),
#  '276': Doctag(offset=276, word_count=73, doc_count=1),
#  '277': Doctag(offset=277, word_count=168, doc_count=1),
#  '278': Doctag(offset=278, word_count=53, doc_count=1),
#  '279': Doctag(offset=279, word_count=79, doc_count=1),
#  '280': Doctag(offset=280, word_count=83, doc_count=1),
#  '281': Doctag(offset=281, word_count=64, doc_count=1),
#  '282': Doctag(offset=282, word_count=132, doc_count=1),
#  '283': Doctag(offset=283, word_count=51, doc_count=1),
#  '284': Doctag(offset=284, word_count=106, doc_count=1),
#  '285': Doctag(offset=285, word_count=60, doc_count=1),
#  '286': Doctag(offset=286, word_count=76, doc_count=1),
#  '287': Doctag(offset=287, word_count=128, doc_count=1),
#  '288': Doctag(offset=288, word_count=81, doc_count=1),
#  '289': Doctag(offset=289, word_count=50, doc_count=1),
#  '290': Doctag(offset=290, word_count=94, doc_count=1),
#  '291': Doctag(offset=291, word_count=38, doc_count=1),
#  '292': Doctag(offset=292, word_count=133, doc_count=1),
#  '293': Doctag(offset=293, word_count=96, doc_count=1),
#  '294': Doctag(offset=294, word_count=107, doc_count=1),
#  '295': Doctag(offset=295, word_count=82, doc_count=1),
#  '296': Doctag(offset=296, word_count=104, doc_count=1),
#  '297': Doctag(offset=297, word_count=62, doc_count=1),
#  '298': Doctag(offset=298, word_count=74, doc_count=1),
#  '299': Doctag(offset=299, word_count=198, doc_count=1),
#  '300': Doctag(offset=300, word_count=81, doc_count=1),
#  '301': Doctag(offset=301, word_count=84, doc_count=1),
#  '302': Doctag(offset=302, word_count=84, doc_count=1),
#  '303': Doctag(offset=303, word_count=72, doc_count=1),
#  '304': Doctag(offset=304, word_count=342, doc_count=1),
#  '305': Doctag(offset=305, word_count=65, doc_count=1),
#  '306': Doctag(offset=306, word_count=24, doc_count=1),
#  '307': Doctag(offset=307, word_count=28, doc_count=1),
#  '308': Doctag(offset=308, word_count=34, doc_count=1),
#  '309': Doctag(offset=309, word_count=138, doc_count=1),
#  '310': Doctag(offset=310, word_count=29, doc_count=1),
#  '311': Doctag(offset=311, word_count=134, doc_count=1),
#  '312': Doctag(offset=312, word_count=51, doc_count=1),
#  '313': Doctag(offset=313, word_count=97, doc_count=1),
#  '314': Doctag(offset=314, word_count=46, doc_count=1),
#  '315': Doctag(offset=315, word_count=121, doc_count=1),
#  '316': Doctag(offset=316, word_count=58, doc_count=1),
#  '317': Doctag(offset=317, word_count=135, doc_count=1),
#  '318': Doctag(offset=318, word_count=59, doc_count=1),
#  '319': Doctag(offset=319, word_count=50, doc_count=1),
#  '320': Doctag(offset=320, word_count=134, doc_count=1),
#  '321': Doctag(offset=321, word_count=58, doc_count=1),
#  '322': Doctag(offset=322, word_count=275, doc_count=1),
#  '323': Doctag(offset=323, word_count=64, doc_count=1),
#  '324': Doctag(offset=324, word_count=67, doc_count=1),
#  '325': Doctag(offset=325, word_count=112, doc_count=1),
#  '326': Doctag(offset=326, word_count=15, doc_count=1),
#  '327': Doctag(offset=327, word_count=97, doc_count=1),
#  '328': Doctag(offset=328, word_count=127, doc_count=1),
#  '329': Doctag(offset=329, word_count=90, doc_count=1),
#  '330': Doctag(offset=330, word_count=49, doc_count=1),
#  '331': Doctag(offset=331, word_count=60, doc_count=1),
#  '332': Doctag(offset=332, word_count=126, doc_count=1),
#  '333': Doctag(offset=333, word_count=267, doc_count=1),
#  '334': Doctag(offset=334, word_count=80, doc_count=1),
#  '335': Doctag(offset=335, word_count=323, doc_count=1),
#  '336': Doctag(offset=336, word_count=72, doc_count=1),
#  '337': Doctag(offset=337, word_count=82, doc_count=1),
#  '338': Doctag(offset=338, word_count=117, doc_count=1),
#  '339': Doctag(offset=339, word_count=388, doc_count=1),
#  '340': Doctag(offset=340, word_count=219, doc_count=1),
#  '341': Doctag(offset=341, word_count=75, doc_count=1),
#  '342': Doctag(offset=342, word_count=20, doc_count=1),
#  '343': Doctag(offset=343, word_count=142, doc_count=1),
#  '344': Doctag(offset=344, word_count=74, doc_count=1),
#  '345': Doctag(offset=345, word_count=53, doc_count=1),
#  '346': Doctag(offset=346, word_count=24, doc_count=1),
#  '347': Doctag(offset=347, word_count=144, doc_count=1),
#  '348': Doctag(offset=348, word_count=28, doc_count=1),
#  '349': Doctag(offset=349, word_count=45, doc_count=1),
#  '350': Doctag(offset=350, word_count=60, doc_count=1),
#  '351': Doctag(offset=351, word_count=338, doc_count=1),
#  '352': Doctag(offset=352, word_count=145, doc_count=1),
#  '353': Doctag(offset=353, word_count=51, doc_count=1),
#  '354': Doctag(offset=354, word_count=75, doc_count=1),
#  '355': Doctag(offset=355, word_count=49, doc_count=1),
#  '356': Doctag(offset=356, word_count=38, doc_count=1),
#  '357': Doctag(offset=357, word_count=41, doc_count=1),
#  '358': Doctag(offset=358, word_count=38, doc_count=1),
#  '359': Doctag(offset=359, word_count=134, doc_count=1),
#  '360': Doctag(offset=360, word_count=395, doc_count=1),
#  '361': Doctag(offset=361, word_count=52, doc_count=1),
#  '362': Doctag(offset=362, word_count=47, doc_count=1),
#  '363': Doctag(offset=363, word_count=62, doc_count=1),
#  '364': Doctag(offset=364, word_count=28, doc_count=1),
#  '365': Doctag(offset=365, word_count=29, doc_count=1),
#  '366': Doctag(offset=366, word_count=79, doc_count=1),
#  '367': Doctag(offset=367, word_count=112, doc_count=1),
#  '368': Doctag(offset=368, word_count=173, doc_count=1),
#  '369': Doctag(offset=369, word_count=66, doc_count=1),
#  '370': Doctag(offset=370, word_count=50, doc_count=1),
#  '371': Doctag(offset=371, word_count=145, doc_count=1),
#  '372': Doctag(offset=372, word_count=66, doc_count=1),
#  '373': Doctag(offset=373, word_count=100, doc_count=1),
#  '374': Doctag(offset=374, word_count=24, doc_count=1),
#  '375': Doctag(offset=375, word_count=60, doc_count=1),
#  '376': Doctag(offset=376, word_count=220, doc_count=1),
#  '377': Doctag(offset=377, word_count=48, doc_count=1),
#  '378': Doctag(offset=378, word_count=67, doc_count=1),
#  '379': Doctag(offset=379, word_count=95, doc_count=1),
#  '380': Doctag(offset=380, word_count=62, doc_count=1),
#  '381': Doctag(offset=381, word_count=61, doc_count=1),
#  '382': Doctag(offset=382, word_count=82, doc_count=1),
#  '383': Doctag(offset=383, word_count=58, doc_count=1),
#  '384': Doctag(offset=384, word_count=80, doc_count=1),
#  '385': Doctag(offset=385, word_count=152, doc_count=1),
#  '386': Doctag(offset=386, word_count=22, doc_count=1),
#  '387': Doctag(offset=387, word_count=80, doc_count=1),
#  '388': Doctag(offset=388, word_count=170, doc_count=1),
#  '389': Doctag(offset=389, word_count=51, doc_count=1),
#  '390': Doctag(offset=390, word_count=54, doc_count=1),
#  '391': Doctag(offset=391, word_count=142, doc_count=1),
#  '392': Doctag(offset=392, word_count=55, doc_count=1),
#  '393': Doctag(offset=393, word_count=139, doc_count=1),
#  '394': Doctag(offset=394, word_count=190, doc_count=1),
#  '395': Doctag(offset=395, word_count=47, doc_count=1),
#  '396': Doctag(offset=396, word_count=70, doc_count=1),
#  '397': Doctag(offset=397, word_count=149, doc_count=1),
#  '398': Doctag(offset=398, word_count=15, doc_count=1),
#  '399': Doctag(offset=399, word_count=51, doc_count=1),
#  '400': Doctag(offset=400, word_count=237, doc_count=1),
#  '401': Doctag(offset=401, word_count=147, doc_count=1),
#  '402': Doctag(offset=402, word_count=253, doc_count=1),
#  '403': Doctag(offset=403, word_count=34, doc_count=1),
#  '404': Doctag(offset=404, word_count=83, doc_count=1),
#  '405': Doctag(offset=405, word_count=20, doc_count=1),
#  '406': Doctag(offset=406, word_count=82, doc_count=1),
#  '407': Doctag(offset=407, word_count=79, doc_count=1),
#  '408': Doctag(offset=408, word_count=60, doc_count=1),
#  '409': Doctag(offset=409, word_count=32, doc_count=1),
#  '410': Doctag(offset=410, word_count=10, doc_count=1),
#  '411': Doctag(offset=411, word_count=45, doc_count=1),
#  '412': Doctag(offset=412, word_count=202, doc_count=1),
#  '413': Doctag(offset=413, word_count=302, doc_count=1),
#  '414': Doctag(offset=414, word_count=65, doc_count=1),
#  '415': Doctag(offset=415, word_count=46, doc_count=1),
#  '416': Doctag(offset=416, word_count=135, doc_count=1),
#  '417': Doctag(offset=417, word_count=89, doc_count=1),
#  '418': Doctag(offset=418, word_count=161, doc_count=1),
#  '419': Doctag(offset=419, word_count=51, doc_count=1),
#  '420': Doctag(offset=420, word_count=116, doc_count=1),
#  '421': Doctag(offset=421, word_count=125, doc_count=1),
#  '422': Doctag(offset=422, word_count=101, doc_count=1),
#  '423': Doctag(offset=423, word_count=48, doc_count=1),
#  '424': Doctag(offset=424, word_count=47, doc_count=1),
#  '425': Doctag(offset=425, word_count=35, doc_count=1),
#  '426': Doctag(offset=426, word_count=55, doc_count=1),
#  '427': Doctag(offset=427, word_count=240, doc_count=1),
#  '428': Doctag(offset=428, word_count=66, doc_count=1),
#  '429': Doctag(offset=429, word_count=220, doc_count=1),
#  '430': Doctag(offset=430, word_count=37, doc_count=1),
#  '431': Doctag(offset=431, word_count=272, doc_count=1),
#  '432': Doctag(offset=432, word_count=107, doc_count=1),
#  '433': Doctag(offset=433, word_count=69, doc_count=1),
#  '434': Doctag(offset=434, word_count=177, doc_count=1),
#  '435': Doctag(offset=435, word_count=49, doc_count=1),
#  '436': Doctag(offset=436, word_count=47, doc_count=1),
#  '437': Doctag(offset=437, word_count=147, doc_count=1),
#  '438': Doctag(offset=438, word_count=172, doc_count=1),
#  '439': Doctag(offset=439, word_count=108, doc_count=1),
#  '440': Doctag(offset=440, word_count=149, doc_count=1),
#  '441': Doctag(offset=441, word_count=75, doc_count=1),
#  '442': Doctag(offset=442, word_count=77, doc_count=1),
#  '443': Doctag(offset=443, word_count=37, doc_count=1),
#  '444': Doctag(offset=444, word_count=297, doc_count=1),
#  '445': Doctag(offset=445, word_count=64, doc_count=1),
#  '446': Doctag(offset=446, word_count=34, doc_count=1),
#  '447': Doctag(offset=447, word_count=64, doc_count=1),
#  '448': Doctag(offset=448, word_count=49, doc_count=1),
#  '449': Doctag(offset=449, word_count=37, doc_count=1),
#  '450': Doctag(offset=450, word_count=62, doc_count=1),
#  '451': Doctag(offset=451, word_count=47, doc_count=1),
#  '452': Doctag(offset=452, word_count=63, doc_count=1),
#  '453': Doctag(offset=453, word_count=54, doc_count=1),
#  '454': Doctag(offset=454, word_count=76, doc_count=1),
#  '455': Doctag(offset=455, word_count=126, doc_count=1),
#  '456': Doctag(offset=456, word_count=57, doc_count=1),
#  '457': Doctag(offset=457, word_count=225, doc_count=1),
#  '458': Doctag(offset=458, word_count=76, doc_count=1),
#  '459': Doctag(offset=459, word_count=197, doc_count=1),
#  '460': Doctag(offset=460, word_count=71, doc_count=1),
#  '461': Doctag(offset=461, word_count=53, doc_count=1),
#  '462': Doctag(offset=462, word_count=79, doc_count=1),
#  '463': Doctag(offset=463, word_count=122, doc_count=1),
#  '464': Doctag(offset=464, word_count=78, doc_count=1),
#  '465': Doctag(offset=465, word_count=40, doc_count=1),
#  '466': Doctag(offset=466, word_count=128, doc_count=1),
#  '467': Doctag(offset=467, word_count=43, doc_count=1),
#  '468': Doctag(offset=468, word_count=143, doc_count=1),
#  '469': Doctag(offset=469, word_count=140, doc_count=1),
#  '470': Doctag(offset=470, word_count=68, doc_count=1),
#  '471': Doctag(offset=471, word_count=106, doc_count=1),
#  '472': Doctag(offset=472, word_count=422, doc_count=1),
#  '473': Doctag(offset=473, word_count=145, doc_count=1),
#  '474': Doctag(offset=474, word_count=69, doc_count=1),
#  '475': Doctag(offset=475, word_count=116, doc_count=1),
#  '476': Doctag(offset=476, word_count=83, doc_count=1),
#  '477': Doctag(offset=477, word_count=38, doc_count=1),
#  '478': Doctag(offset=478, word_count=73, doc_count=1),
#  '479': Doctag(offset=479, word_count=16, doc_count=1),
#  '480': Doctag(offset=480, word_count=37, doc_count=1),
#  '481': Doctag(offset=481, word_count=379, doc_count=1),
#  '482': Doctag(offset=482, word_count=213, doc_count=1),
#  '483': Doctag(offset=483, word_count=88, doc_count=1),
#  '484': Doctag(offset=484, word_count=98, doc_count=1),
#  '485': Doctag(offset=485, word_count=22, doc_count=1),
#  '486': Doctag(offset=486, word_count=82, doc_count=1),
#  '487': Doctag(offset=487, word_count=49, doc_count=1),
#  '488': Doctag(offset=488, word_count=78, doc_count=1),
#  '489': Doctag(offset=489, word_count=53, doc_count=1),
#  '490': Doctag(offset=490, word_count=23, doc_count=1),
#  '491': Doctag(offset=491, word_count=336, doc_count=1),
#  '492': Doctag(offset=492, word_count=325, doc_count=1),
#  '493': Doctag(offset=493, word_count=68, doc_count=1),
#  '494': Doctag(offset=494, word_count=40, doc_count=1),
#  '495': Doctag(offset=495, word_count=68, doc_count=1),
#  '496': Doctag(offset=496, word_count=146, doc_count=1),
#  '497': Doctag(offset=497, word_count=85, doc_count=1),
#  '498': Doctag(offset=498, word_count=393, doc_count=1),
#  '499': Doctag(offset=499, word_count=110, doc_count=1),
#  '500': Doctag(offset=500, word_count=631, doc_count=1),
#  '501': Doctag(offset=501, word_count=182, doc_count=1),
#  '502': Doctag(offset=502, word_count=188, doc_count=1),
#  '503': Doctag(offset=503, word_count=61, doc_count=1),
#  '504': Doctag(offset=504, word_count=33, doc_count=1),
#  '505': Doctag(offset=505, word_count=76, doc_count=1),
#  '506': Doctag(offset=506, word_count=132, doc_count=1),
#  '507': Doctag(offset=507, word_count=197, doc_count=1),
#  '508': Doctag(offset=508, word_count=95, doc_count=1),
#  '509': Doctag(offset=509, word_count=58, doc_count=1),
#  '510': Doctag(offset=510, word_count=164, doc_count=1),
#  '511': Doctag(offset=511, word_count=53, doc_count=1),
#  '512': Doctag(offset=512, word_count=217, doc_count=1),
#  '513': Doctag(offset=513, word_count=144, doc_count=1),
#  '514': Doctag(offset=514, word_count=45, doc_count=1),
#  '515': Doctag(offset=515, word_count=75, doc_count=1),
#  '516': Doctag(offset=516, word_count=110, doc_count=1),
#  '517': Doctag(offset=517, word_count=83, doc_count=1),
#  '518': Doctag(offset=518, word_count=42, doc_count=1),
#  '519': Doctag(offset=519, word_count=31, doc_count=1),
#  '520': Doctag(offset=520, word_count=13, doc_count=1),
#  '521': Doctag(offset=521, word_count=139, doc_count=1),
#  '522': Doctag(offset=522, word_count=75, doc_count=1),
#  '523': Doctag(offset=523, word_count=91, doc_count=1),
#  '524': Doctag(offset=524, word_count=80, doc_count=1),
#  '525': Doctag(offset=525, word_count=60, doc_count=1),
#  '526': Doctag(offset=526, word_count=129, doc_count=1),
#  '527': Doctag(offset=527, word_count=82, doc_count=1),
#  '528': Doctag(offset=528, word_count=68, doc_count=1),
#  '529': Doctag(offset=529, word_count=76, doc_count=1),
#  '530': Doctag(offset=530, word_count=237, doc_count=1),
#  '531': Doctag(offset=531, word_count=69, doc_count=1),
#  '532': Doctag(offset=532, word_count=27, doc_count=1),
#  '533': Doctag(offset=533, word_count=386, doc_count=1),
#  '534': Doctag(offset=534, word_count=91, doc_count=1),
#  '535': Doctag(offset=535, word_count=171, doc_count=1),
#  '536': Doctag(offset=536, word_count=132, doc_count=1),
#  '537': Doctag(offset=537, word_count=81, doc_count=1),
#  '538': Doctag(offset=538, word_count=22, doc_count=1),
#  '539': Doctag(offset=539, word_count=41, doc_count=1),
#  '540': Doctag(offset=540, word_count=210, doc_count=1),
#  '541': Doctag(offset=541, word_count=212, doc_count=1),
#  '542': Doctag(offset=542, word_count=23, doc_count=1),
#  '543': Doctag(offset=543, word_count=108, doc_count=1),
#  '544': Doctag(offset=544, word_count=101, doc_count=1),
#  '545': Doctag(offset=545, word_count=54, doc_count=1),
#  '546': Doctag(offset=546, word_count=127, doc_count=1),
#  '547': Doctag(offset=547, word_count=142, doc_count=1),
#  '548': Doctag(offset=548, word_count=62, doc_count=1),
#  '549': Doctag(offset=549, word_count=157, doc_count=1),
#  '550': Doctag(offset=550, word_count=56, doc_count=1),
#  '551': Doctag(offset=551, word_count=118, doc_count=1),
#  '552': Doctag(offset=552, word_count=189, doc_count=1),
#  '553': Doctag(offset=553, word_count=332, doc_count=1),
#  '554': Doctag(offset=554, word_count=23, doc_count=1),
#  '555': Doctag(offset=555, word_count=274, doc_count=1),
#  '556': Doctag(offset=556, word_count=325, doc_count=1),
#  '557': Doctag(offset=557, word_count=123, doc_count=1),
#  '558': Doctag(offset=558, word_count=51, doc_count=1),
#  '559': Doctag(offset=559, word_count=82, doc_count=1),
#  '560': Doctag(offset=560, word_count=85, doc_count=1),
#  '561': Doctag(offset=561, word_count=61, doc_count=1),
#  '562': Doctag(offset=562, word_count=419, doc_count=1),
#  '563': Doctag(offset=563, word_count=92, doc_count=1),
#  '564': Doctag(offset=564, word_count=100, doc_count=1),
#  '565': Doctag(offset=565, word_count=119, doc_count=1),
#  '566': Doctag(offset=566, word_count=22, doc_count=1),
#  '567': Doctag(offset=567, word_count=23, doc_count=1),
#  '568': Doctag(offset=568, word_count=94, doc_count=1),
#  '569': Doctag(offset=569, word_count=139, doc_count=1),
#  '570': Doctag(offset=570, word_count=99, doc_count=1),
#  '571': Doctag(offset=571, word_count=54, doc_count=1),
#  '572': Doctag(offset=572, word_count=260, doc_count=1),
#  '573': Doctag(offset=573, word_count=256, doc_count=1),
#  '574': Doctag(offset=574, word_count=144, doc_count=1),
#  '575': Doctag(offset=575, word_count=63, doc_count=1),
#  '576': Doctag(offset=576, word_count=133, doc_count=1),
#  '577': Doctag(offset=577, word_count=44, doc_count=1),
#  '578': Doctag(offset=578, word_count=40, doc_count=1),
#  '579': Doctag(offset=579, word_count=78, doc_count=1),
#  '580': Doctag(offset=580, word_count=34, doc_count=1),
#  '581': Doctag(offset=581, word_count=42, doc_count=1),
#  '582': Doctag(offset=582, word_count=103, doc_count=1),
#  '583': Doctag(offset=583, word_count=59, doc_count=1),
#  '584': Doctag(offset=584, word_count=62, doc_count=1),
#  '585': Doctag(offset=585, word_count=36, doc_count=1),
#  '586': Doctag(offset=586, word_count=65, doc_count=1),
#  '587': Doctag(offset=587, word_count=55, doc_count=1),
#  '588': Doctag(offset=588, word_count=67, doc_count=1),
#  '589': Doctag(offset=589, word_count=171, doc_count=1),
#  '590': Doctag(offset=590, word_count=295, doc_count=1),
#  '591': Doctag(offset=591, word_count=78, doc_count=1),
#  '592': Doctag(offset=592, word_count=101, doc_count=1),
#  '593': Doctag(offset=593, word_count=293, doc_count=1),
#  '594': Doctag(offset=594, word_count=56, doc_count=1),
#  '595': Doctag(offset=595, word_count=84, doc_count=1),
#  '596': Doctag(offset=596, word_count=44, doc_count=1),
#  '597': Doctag(offset=597, word_count=66, doc_count=1),
#  '598': Doctag(offset=598, word_count=33, doc_count=1),
#  '599': Doctag(offset=599, word_count=44, doc_count=1),
#  '600': Doctag(offset=600, word_count=233, doc_count=1),
#  '601': Doctag(offset=601, word_count=24, doc_count=1),
#  '602': Doctag(offset=602, word_count=80, doc_count=1),
#  '603': Doctag(offset=603, word_count=90, doc_count=1),
#  '604': Doctag(offset=604, word_count=104, doc_count=1),
#  '605': Doctag(offset=605, word_count=84, doc_count=1),
#  '606': Doctag(offset=606, word_count=70, doc_count=1),
#  '607': Doctag(offset=607, word_count=203, doc_count=1),
#  '608': Doctag(offset=608, word_count=95, doc_count=1),
#  '609': Doctag(offset=609, word_count=45, doc_count=1),
#  '610': Doctag(offset=610, word_count=58, doc_count=1),
#  '611': Doctag(offset=611, word_count=36, doc_count=1),
#  '612': Doctag(offset=612, word_count=103, doc_count=1),
#  '613': Doctag(offset=613, word_count=17, doc_count=1),
#  '614': Doctag(offset=614, word_count=90, doc_count=1),
#  '615': Doctag(offset=615, word_count=70, doc_count=1),
#  '616': Doctag(offset=616, word_count=39, doc_count=1),
#  '617': Doctag(offset=617, word_count=86, doc_count=1),
#  '618': Doctag(offset=618, word_count=139, doc_count=1),
#  '619': Doctag(offset=619, word_count=52, doc_count=1),
#  '620': Doctag(offset=620, word_count=44, doc_count=1),
#  '621': Doctag(offset=621, word_count=60, doc_count=1),
#  '622': Doctag(offset=622, word_count=34, doc_count=1),
#  '623': Doctag(offset=623, word_count=62, doc_count=1),
#  '624': Doctag(offset=624, word_count=18, doc_count=1),
#  '625': Doctag(offset=625, word_count=516, doc_count=1),
#  '626': Doctag(offset=626, word_count=53, doc_count=1),
#  '627': Doctag(offset=627, word_count=85, doc_count=1),
#  '628': Doctag(offset=628, word_count=111, doc_count=1),
#  '629': Doctag(offset=629, word_count=65, doc_count=1),
#  '630': Doctag(offset=630, word_count=54, doc_count=1),
#  '631': Doctag(offset=631, word_count=245, doc_count=1),
#  '632': Doctag(offset=632, word_count=182, doc_count=1),
#  '633': Doctag(offset=633, word_count=194, doc_count=1),
#  '634': Doctag(offset=634, word_count=62, doc_count=1),
#  '635': Doctag(offset=635, word_count=52, doc_count=1),
#  '636': Doctag(offset=636, word_count=72, doc_count=1),
#  '637': Doctag(offset=637, word_count=275, doc_count=1),
#  '638': Doctag(offset=638, word_count=57, doc_count=1),
#  '639': Doctag(offset=639, word_count=86, doc_count=1),
#  '640': Doctag(offset=640, word_count=84, doc_count=1),
#  '641': Doctag(offset=641, word_count=54, doc_count=1),
#  '642': Doctag(offset=642, word_count=71, doc_count=1),
#  '643': Doctag(offset=643, word_count=65, doc_count=1),
#  '644': Doctag(offset=644, word_count=185, doc_count=1),
#  '645': Doctag(offset=645, word_count=30, doc_count=1),
#  '646': Doctag(offset=646, word_count=64, doc_count=1),
#  '647': Doctag(offset=647, word_count=58, doc_count=1),
#  '648': Doctag(offset=648, word_count=114, doc_count=1),
#  '649': Doctag(offset=649, word_count=165, doc_count=1),
#  '650': Doctag(offset=650, word_count=54, doc_count=1),
#  '651': Doctag(offset=651, word_count=84, doc_count=1),
#  '652': Doctag(offset=652, word_count=73, doc_count=1),
#  '653': Doctag(offset=653, word_count=171, doc_count=1),
#  '654': Doctag(offset=654, word_count=71, doc_count=1),
#  '655': Doctag(offset=655, word_count=27, doc_count=1),
#  '656': Doctag(offset=656, word_count=110, doc_count=1),
#  '657': Doctag(offset=657, word_count=134, doc_count=1),
#  '658': Doctag(offset=658, word_count=71, doc_count=1),
#  '659': Doctag(offset=659, word_count=51, doc_count=1),
#  '660': Doctag(offset=660, word_count=57, doc_count=1),
#  '661': Doctag(offset=661, word_count=50, doc_count=1),
#  '662': Doctag(offset=662, word_count=46, doc_count=1),
#  '663': Doctag(offset=663, word_count=104, doc_count=1),
#  '664': Doctag(offset=664, word_count=65, doc_count=1),
#  '665': Doctag(offset=665, word_count=122, doc_count=1),
#  '666': Doctag(offset=666, word_count=49, doc_count=1),
#  '667': Doctag(offset=667, word_count=151, doc_count=1),
#  '668': Doctag(offset=668, word_count=109, doc_count=1),
#  '669': Doctag(offset=669, word_count=25, doc_count=1),
#  '670': Doctag(offset=670, word_count=36, doc_count=1),
#  '671': Doctag(offset=671, word_count=58, doc_count=1),
#  '672': Doctag(offset=672, word_count=55, doc_count=1),
#  '673': Doctag(offset=673, word_count=375, doc_count=1),
#  '674': Doctag(offset=674, word_count=51, doc_count=1),
#  '675': Doctag(offset=675, word_count=271, doc_count=1),
#  '676': Doctag(offset=676, word_count=77, doc_count=1),
#  '677': Doctag(offset=677, word_count=73, doc_count=1),
#  '678': Doctag(offset=678, word_count=55, doc_count=1),
#  '679': Doctag(offset=679, word_count=77, doc_count=1),
#  '680': Doctag(offset=680, word_count=47, doc_count=1),
#  '681': Doctag(offset=681, word_count=171, doc_count=1),
#  '682': Doctag(offset=682, word_count=275, doc_count=1),
#  '683': Doctag(offset=683, word_count=67, doc_count=1),
#  '684': Doctag(offset=684, word_count=124, doc_count=1),
#  '685': Doctag(offset=685, word_count=28, doc_count=1),
#  '686': Doctag(offset=686, word_count=31, doc_count=1),
#  '687': Doctag(offset=687, word_count=43, doc_count=1),
#  '688': Doctag(offset=688, word_count=61, doc_count=1),
#  '689': Doctag(offset=689, word_count=43, doc_count=1),
#  '690': Doctag(offset=690, word_count=143, doc_count=1),
#  '691': Doctag(offset=691, word_count=47, doc_count=1),
#  '692': Doctag(offset=692, word_count=66, doc_count=1),
#  '693': Doctag(offset=693, word_count=279, doc_count=1),
#  '694': Doctag(offset=694, word_count=423, doc_count=1),
#  '695': Doctag(offset=695, word_count=113, doc_count=1),
#  '696': Doctag(offset=696, word_count=53, doc_count=1),
#  '697': Doctag(offset=697, word_count=297, doc_count=1),
#  '698': Doctag(offset=698, word_count=161, doc_count=1),
#  '699': Doctag(offset=699, word_count=353, doc_count=1),
#  '700': Doctag(offset=700, word_count=76, doc_count=1),
#  '701': Doctag(offset=701, word_count=99, doc_count=1),
#  '702': Doctag(offset=702, word_count=24, doc_count=1),
#  '703': Doctag(offset=703, word_count=136, doc_count=1),
#  '704': Doctag(offset=704, word_count=45, doc_count=1),
#  '705': Doctag(offset=705, word_count=113, doc_count=1),
#  '706': Doctag(offset=706, word_count=132, doc_count=1),
#  '707': Doctag(offset=707, word_count=300, doc_count=1),
#  '708': Doctag(offset=708, word_count=60, doc_count=1),
#  '709': Doctag(offset=709, word_count=61, doc_count=1),
#  '710': Doctag(offset=710, word_count=29, doc_count=1),
#  '711': Doctag(offset=711, word_count=168, doc_count=1),
#  '712': Doctag(offset=712, word_count=97, doc_count=1),
#  '713': Doctag(offset=713, word_count=24, doc_count=1),
#  '714': Doctag(offset=714, word_count=111, doc_count=1),
#  '715': Doctag(offset=715, word_count=24, doc_count=1),
#  '716': Doctag(offset=716, word_count=71, doc_count=1),
#  '717': Doctag(offset=717, word_count=194, doc_count=1),
#  '718': Doctag(offset=718, word_count=261, doc_count=1),
#  '719': Doctag(offset=719, word_count=50, doc_count=1),
#  '720': Doctag(offset=720, word_count=290, doc_count=1),
#  '721': Doctag(offset=721, word_count=64, doc_count=1),
#  '722': Doctag(offset=722, word_count=153, doc_count=1),
#  '723': Doctag(offset=723, word_count=293, doc_count=1),
#  '724': Doctag(offset=724, word_count=104, doc_count=1),
#  '725': Doctag(offset=725, word_count=174, doc_count=1),
#  '726': Doctag(offset=726, word_count=84, doc_count=1),
#  '727': Doctag(offset=727, word_count=148, doc_count=1),
#  '728': Doctag(offset=728, word_count=229, doc_count=1),
#  '729': Doctag(offset=729, word_count=65, doc_count=1),
#  '730': Doctag(offset=730, word_count=221, doc_count=1),
#  '731': Doctag(offset=731, word_count=54, doc_count=1),
#  '732': Doctag(offset=732, word_count=58, doc_count=1),
#  '733': Doctag(offset=733, word_count=83, doc_count=1),
#  '734': Doctag(offset=734, word_count=28, doc_count=1),
#  '735': Doctag(offset=735, word_count=30, doc_count=1),
#  '736': Doctag(offset=736, word_count=72, doc_count=1),
#  '737': Doctag(offset=737, word_count=115, doc_count=1),
#  '738': Doctag(offset=738, word_count=57, doc_count=1),
#  '739': Doctag(offset=739, word_count=72, doc_count=1),
#  '740': Doctag(offset=740, word_count=76, doc_count=1),
#  '741': Doctag(offset=741, word_count=193, doc_count=1),
#  '742': Doctag(offset=742, word_count=103, doc_count=1),
#  '743': Doctag(offset=743, word_count=104, doc_count=1),
#  '744': Doctag(offset=744, word_count=222, doc_count=1),
#  '745': Doctag(offset=745, word_count=103, doc_count=1),
#  '746': Doctag(offset=746, word_count=90, doc_count=1),
#  '747': Doctag(offset=747, word_count=37, doc_count=1),
#  '748': Doctag(offset=748, word_count=137, doc_count=1),
#  '749': Doctag(offset=749, word_count=40, doc_count=1),
#  '750': Doctag(offset=750, word_count=68, doc_count=1),
#  '751': Doctag(offset=751, word_count=71, doc_count=1),
#  '752': Doctag(offset=752, word_count=117, doc_count=1),
#  '753': Doctag(offset=753, word_count=82, doc_count=1),
#  '754': Doctag(offset=754, word_count=54, doc_count=1),
#  '755': Doctag(offset=755, word_count=73, doc_count=1),
#  '756': Doctag(offset=756, word_count=85, doc_count=1),
#  '757': Doctag(offset=757, word_count=55, doc_count=1),
#  '758': Doctag(offset=758, word_count=28, doc_count=1),
#  '759': Doctag(offset=759, word_count=134, doc_count=1),
#  '760': Doctag(offset=760, word_count=96, doc_count=1),
#  '761': Doctag(offset=761, word_count=27, doc_count=1),
#  '762': Doctag(offset=762, word_count=230, doc_count=1),
#  '763': Doctag(offset=763, word_count=45, doc_count=1),
#  '764': Doctag(offset=764, word_count=36, doc_count=1),
#  '765': Doctag(offset=765, word_count=103, doc_count=1),
#  '766': Doctag(offset=766, word_count=106, doc_count=1),
#  '767': Doctag(offset=767, word_count=47, doc_count=1),
#  '768': Doctag(offset=768, word_count=58, doc_count=1),
#  '769': Doctag(offset=769, word_count=21, doc_count=1),
#  '770': Doctag(offset=770, word_count=80, doc_count=1),
#  '771': Doctag(offset=771, word_count=148, doc_count=1),
#  '772': Doctag(offset=772, word_count=86, doc_count=1),
#  '773': Doctag(offset=773, word_count=51, doc_count=1),
#  '774': Doctag(offset=774, word_count=223, doc_count=1),
#  '775': Doctag(offset=775, word_count=89, doc_count=1),
#  '776': Doctag(offset=776, word_count=124, doc_count=1),
#  '777': Doctag(offset=777, word_count=122, doc_count=1),
#  '778': Doctag(offset=778, word_count=35, doc_count=1),
#  '779': Doctag(offset=779, word_count=43, doc_count=1),
#  '780': Doctag(offset=780, word_count=384, doc_count=1),
#  '781': Doctag(offset=781, word_count=76, doc_count=1),
#  '782': Doctag(offset=782, word_count=197, doc_count=1),
#  '783': Doctag(offset=783, word_count=150, doc_count=1),
#  '784': Doctag(offset=784, word_count=95, doc_count=1),
#  '785': Doctag(offset=785, word_count=48, doc_count=1),
#  '786': Doctag(offset=786, word_count=130, doc_count=1),
#  '787': Doctag(offset=787, word_count=36, doc_count=1),
#  '788': Doctag(offset=788, word_count=130, doc_count=1),
#  '789': Doctag(offset=789, word_count=76, doc_count=1),
#  '790': Doctag(offset=790, word_count=135, doc_count=1),
#  '791': Doctag(offset=791, word_count=173, doc_count=1),
#  '792': Doctag(offset=792, word_count=62, doc_count=1),
#  '793': Doctag(offset=793, word_count=69, doc_count=1),
#  '794': Doctag(offset=794, word_count=89, doc_count=1),
#  '795': Doctag(offset=795, word_count=109, doc_count=1),
#  '796': Doctag(offset=796, word_count=78, doc_count=1),
#  '797': Doctag(offset=797, word_count=61, doc_count=1),
#  '798': Doctag(offset=798, word_count=110, doc_count=1),
#  '799': Doctag(offset=799, word_count=60, doc_count=1),
#  '800': Doctag(offset=800, word_count=86, doc_count=1),
#  '801': Doctag(offset=801, word_count=102, doc_count=1),
#  '802': Doctag(offset=802, word_count=357, doc_count=1),
#  '803': Doctag(offset=803, word_count=48, doc_count=1),
#  '804': Doctag(offset=804, word_count=26, doc_count=1),
#  '805': Doctag(offset=805, word_count=52, doc_count=1),
#  '806': Doctag(offset=806, word_count=81, doc_count=1),
#  '807': Doctag(offset=807, word_count=125, doc_count=1),
#  '808': Doctag(offset=808, word_count=67, doc_count=1),
#  '809': Doctag(offset=809, word_count=219, doc_count=1),
#  '810': Doctag(offset=810, word_count=89, doc_count=1),
#  '811': Doctag(offset=811, word_count=62, doc_count=1),
#  '812': Doctag(offset=812, word_count=64, doc_count=1),
#  '813': Doctag(offset=813, word_count=84, doc_count=1),
#  '814': Doctag(offset=814, word_count=94, doc_count=1),
#  '815': Doctag(offset=815, word_count=92, doc_count=1),
#  '816': Doctag(offset=816, word_count=302, doc_count=1),
#  '817': Doctag(offset=817, word_count=74, doc_count=1),
#  '818': Doctag(offset=818, word_count=58, doc_count=1),
#  '819': Doctag(offset=819, word_count=58, doc_count=1),
#  '820': Doctag(offset=820, word_count=64, doc_count=1),
#  '821': Doctag(offset=821, word_count=146, doc_count=1),
#  '822': Doctag(offset=822, word_count=434, doc_count=1),
#  '823': Doctag(offset=823, word_count=263, doc_count=1),
#  '824': Doctag(offset=824, word_count=223, doc_count=1),
#  '825': Doctag(offset=825, word_count=53, doc_count=1),
#  '826': Doctag(offset=826, word_count=216, doc_count=1),
#  '827': Doctag(offset=827, word_count=148, doc_count=1),
#  '828': Doctag(offset=828, word_count=168, doc_count=1),
#  '829': Doctag(offset=829, word_count=48, doc_count=1),
#  '830': Doctag(offset=830, word_count=231, doc_count=1),
#  '831': Doctag(offset=831, word_count=51, doc_count=1),
#  '832': Doctag(offset=832, word_count=49, doc_count=1),
#  '833': Doctag(offset=833, word_count=453, doc_count=1),
#  '834': Doctag(offset=834, word_count=27, doc_count=1),
#  '835': Doctag(offset=835, word_count=44, doc_count=1),
#  '836': Doctag(offset=836, word_count=152, doc_count=1),
#  '837': Doctag(offset=837, word_count=86, doc_count=1),
#  '838': Doctag(offset=838, word_count=151, doc_count=1),
#  '839': Doctag(offset=839, word_count=49, doc_count=1),
#  '840': Doctag(offset=840, word_count=294, doc_count=1),
#  '841': Doctag(offset=841, word_count=113, doc_count=1),
#  '842': Doctag(offset=842, word_count=51, doc_count=1),
#  '843': Doctag(offset=843, word_count=124, doc_count=1),
#  '844': Doctag(offset=844, word_count=45, doc_count=1),
#  '845': Doctag(offset=845, word_count=31, doc_count=1),
#  '846': Doctag(offset=846, word_count=103, doc_count=1),
#  '847': Doctag(offset=847, word_count=60, doc_count=1),
#  '848': Doctag(offset=848, word_count=54, doc_count=1),
#  '849': Doctag(offset=849, word_count=98, doc_count=1),
#  '850': Doctag(offset=850, word_count=82, doc_count=1),
#  '851': Doctag(offset=851, word_count=37, doc_count=1),
#  '852': Doctag(offset=852, word_count=183, doc_count=1),
#  '853': Doctag(offset=853, word_count=222, doc_count=1),
#  '854': Doctag(offset=854, word_count=66, doc_count=1),
#  '855': Doctag(offset=855, word_count=51, doc_count=1),
#  '856': Doctag(offset=856, word_count=34, doc_count=1),
#  '857': Doctag(offset=857, word_count=152, doc_count=1),
#  '858': Doctag(offset=858, word_count=67, doc_count=1),
#  '859': Doctag(offset=859, word_count=277, doc_count=1),
#  '860': Doctag(offset=860, word_count=54, doc_count=1),
#  '861': Doctag(offset=861, word_count=79, doc_count=1),
#  '862': Doctag(offset=862, word_count=65, doc_count=1),
#  '863': Doctag(offset=863, word_count=147, doc_count=1),
#  '864': Doctag(offset=864, word_count=35, doc_count=1),
#  '865': Doctag(offset=865, word_count=75, doc_count=1),
#  '866': Doctag(offset=866, word_count=61, doc_count=1),
#  '867': Doctag(offset=867, word_count=67, doc_count=1),
#  '868': Doctag(offset=868, word_count=101, doc_count=1),
#  '869': Doctag(offset=869, word_count=141, doc_count=1),
#  '870': Doctag(offset=870, word_count=155, doc_count=1),
#  '871': Doctag(offset=871, word_count=220, doc_count=1),
#  '872': Doctag(offset=872, word_count=225, doc_count=1),
#  '873': Doctag(offset=873, word_count=14, doc_count=1),
#  '874': Doctag(offset=874, word_count=106, doc_count=1),
#  '875': Doctag(offset=875, word_count=181, doc_count=1),
#  '876': Doctag(offset=876, word_count=261, doc_count=1),
#  '877': Doctag(offset=877, word_count=58, doc_count=1),
#  '878': Doctag(offset=878, word_count=218, doc_count=1),
#  '879': Doctag(offset=879, word_count=102, doc_count=1),
#  '880': Doctag(offset=880, word_count=46, doc_count=1),
#  '881': Doctag(offset=881, word_count=178, doc_count=1),
#  '882': Doctag(offset=882, word_count=108, doc_count=1),
#  '883': Doctag(offset=883, word_count=132, doc_count=1),
#  '884': Doctag(offset=884, word_count=46, doc_count=1),
#  '885': Doctag(offset=885, word_count=218, doc_count=1),
#  '886': Doctag(offset=886, word_count=420, doc_count=1),
#  '887': Doctag(offset=887, word_count=45, doc_count=1),
#  '888': Doctag(offset=888, word_count=172, doc_count=1),
#  '889': Doctag(offset=889, word_count=65, doc_count=1),
#  '890': Doctag(offset=890, word_count=139, doc_count=1),
#  '891': Doctag(offset=891, word_count=74, doc_count=1),
#  '892': Doctag(offset=892, word_count=111, doc_count=1),
#  '893': Doctag(offset=893, word_count=194, doc_count=1),
#  '894': Doctag(offset=894, word_count=59, doc_count=1),
#  '895': Doctag(offset=895, word_count=157, doc_count=1),
#  '896': Doctag(offset=896, word_count=239, doc_count=1),
#  '897': Doctag(offset=897, word_count=72, doc_count=1),
#  '898': Doctag(offset=898, word_count=155, doc_count=1),
#  '899': Doctag(offset=899, word_count=337, doc_count=1),
#  '900': Doctag(offset=900, word_count=142, doc_count=1),
#  '901': Doctag(offset=901, word_count=106, doc_count=1),
#  '902': Doctag(offset=902, word_count=93, doc_count=1),
#  '903': Doctag(offset=903, word_count=275, doc_count=1),
#  '904': Doctag(offset=904, word_count=27, doc_count=1),
#  '905': Doctag(offset=905, word_count=86, doc_count=1),
#  '906': Doctag(offset=906, word_count=244, doc_count=1),
#  '907': Doctag(offset=907, word_count=55, doc_count=1),
#  '908': Doctag(offset=908, word_count=70, doc_count=1),
#  '909': Doctag(offset=909, word_count=149, doc_count=1),
#  '910': Doctag(offset=910, word_count=65, doc_count=1),
#  '911': Doctag(offset=911, word_count=41, doc_count=1),
#  '912': Doctag(offset=912, word_count=91, doc_count=1),
#  '913': Doctag(offset=913, word_count=445, doc_count=1),
#  '914': Doctag(offset=914, word_count=8, doc_count=1),
#  '915': Doctag(offset=915, word_count=131, doc_count=1),
#  '916': Doctag(offset=916, word_count=87, doc_count=1),
#  '917': Doctag(offset=917, word_count=49, doc_count=1),
#  '918': Doctag(offset=918, word_count=58, doc_count=1),
#  '919': Doctag(offset=919, word_count=97, doc_count=1),
#  '920': Doctag(offset=920, word_count=27, doc_count=1),
#  '921': Doctag(offset=921, word_count=22, doc_count=1),
#  '922': Doctag(offset=922, word_count=84, doc_count=1),
#  '923': Doctag(offset=923, word_count=111, doc_count=1),
#  '924': Doctag(offset=924, word_count=123, doc_count=1),
#  '925': Doctag(offset=925, word_count=244, doc_count=1),
#  '926': Doctag(offset=926, word_count=263, doc_count=1),
#  '927': Doctag(offset=927, word_count=87, doc_count=1),
#  '928': Doctag(offset=928, word_count=26, doc_count=1),
#  '929': Doctag(offset=929, word_count=52, doc_count=1),
#  '930': Doctag(offset=930, word_count=113, doc_count=1),
#  '931': Doctag(offset=931, word_count=283, doc_count=1),
#  '932': Doctag(offset=932, word_count=474, doc_count=1),
#  '933': Doctag(offset=933, word_count=88, doc_count=1),
#  '934': Doctag(offset=934, word_count=234, doc_count=1),
#  '935': Doctag(offset=935, word_count=130, doc_count=1),
#  '936': Doctag(offset=936, word_count=159, doc_count=1),
#  '937': Doctag(offset=937, word_count=83, doc_count=1),
#  '938': Doctag(offset=938, word_count=81, doc_count=1),
#  '939': Doctag(offset=939, word_count=19, doc_count=1),
#  '940': Doctag(offset=940, word_count=61, doc_count=1),
#  '941': Doctag(offset=941, word_count=80, doc_count=1),
#  '942': Doctag(offset=942, word_count=32, doc_count=1),
#  '943': Doctag(offset=943, word_count=63, doc_count=1),
#  '944': Doctag(offset=944, word_count=146, doc_count=1),
#  '945': Doctag(offset=945, word_count=91, doc_count=1),
#  '946': Doctag(offset=946, word_count=23, doc_count=1),
#  '947': Doctag(offset=947, word_count=293, doc_count=1),
#  '948': Doctag(offset=948, word_count=152, doc_count=1),
#  '949': Doctag(offset=949, word_count=20, doc_count=1),
#  '950': Doctag(offset=950, word_count=60, doc_count=1),
#  '951': Doctag(offset=951, word_count=283, doc_count=1),
#  '952': Doctag(offset=952, word_count=86, doc_count=1),
#  '953': Doctag(offset=953, word_count=116, doc_count=1),
#  '954': Doctag(offset=954, word_count=70, doc_count=1),
#  '955': Doctag(offset=955, word_count=39, doc_count=1),
#  '956': Doctag(offset=956, word_count=52, doc_count=1),
#  '957': Doctag(offset=957, word_count=55, doc_count=1),
#  '958': Doctag(offset=958, word_count=104, doc_count=1),
#  '959': Doctag(offset=959, word_count=85, doc_count=1),
#  '960': Doctag(offset=960, word_count=127, doc_count=1),
#  '961': Doctag(offset=961, word_count=131, doc_count=1),
#  '962': Doctag(offset=962, word_count=117, doc_count=1),
#  '963': Doctag(offset=963, word_count=34, doc_count=1),
#  '964': Doctag(offset=964, word_count=580, doc_count=1),
#  '965': Doctag(offset=965, word_count=156, doc_count=1),
#  '966': Doctag(offset=966, word_count=129, doc_count=1),
#  '967': Doctag(offset=967, word_count=167, doc_count=1),
#  '968': Doctag(offset=968, word_count=57, doc_count=1),
#  '969': Doctag(offset=969, word_count=297, doc_count=1),
#  '970': Doctag(offset=970, word_count=118, doc_count=1),
#  '971': Doctag(offset=971, word_count=112, doc_count=1),
#  '972': Doctag(offset=972, word_count=53, doc_count=1),
#  '973': Doctag(offset=973, word_count=53, doc_count=1),
#  '974': Doctag(offset=974, word_count=62, doc_count=1),
#  '975': Doctag(offset=975, word_count=261, doc_count=1),
#  '976': Doctag(offset=976, word_count=81, doc_count=1),
#  '977': Doctag(offset=977, word_count=405, doc_count=1),
#  '978': Doctag(offset=978, word_count=50, doc_count=1),
#  '979': Doctag(offset=979, word_count=100, doc_count=1),
#  '980': Doctag(offset=980, word_count=67, doc_count=1),
#  '981': Doctag(offset=981, word_count=95, doc_count=1),
#  '982': Doctag(offset=982, word_count=230, doc_count=1),
#  '983': Doctag(offset=983, word_count=71, doc_count=1),
#  '984': Doctag(offset=984, word_count=291, doc_count=1),
#  '985': Doctag(offset=985, word_count=29, doc_count=1),
#  '986': Doctag(offset=986, word_count=118, doc_count=1),
#  '987': Doctag(offset=987, word_count=105, doc_count=1),
#  '988': Doctag(offset=988, word_count=145, doc_count=1),
#  '989': Doctag(offset=989, word_count=176, doc_count=1),
#  '990': Doctag(offset=990, word_count=220, doc_count=1),
#  '991': Doctag(offset=991, word_count=67, doc_count=1),
#  '992': Doctag(offset=992, word_count=331, doc_count=1),
#  '993': Doctag(offset=993, word_count=28, doc_count=1),
#  '994': Doctag(offset=994, word_count=59, doc_count=1),
#  '995': Doctag(offset=995, word_count=73, doc_count=1),
#  '996': Doctag(offset=996, word_count=46, doc_count=1),
#  '997': Doctag(offset=997, word_count=56, doc_count=1),
#  '998': Doctag(offset=998, word_count=187, doc_count=1),
#  '999': Doctag(offset=999, word_count=223, doc_count=1),
#  ...}

# %%
target_doc = '1'

similar_docs = d2v_model.docvecs.most_similar(target_doc, topn=5)
print(similar_docs)
# Out:
# [('22933', 0.4056338965892792), ('1494', 0.3884551525115967), ('23127', 0.34835177659988403), ('3897', 0.3471860885620117), ('22461', 0.34336817264556885)]
# /anaconda2/envs/python36/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# ##### The 5 most similar documents to document[1] are document[22933], document[1494], document[23127], document[3897] and document[22461].

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.decomposition import TruncatedSVD
k = 10

# reduce the dimensionality of the input
# %time svd = TruncatedSVD(n_components=300).fit_transform(X)

agg = AgglomerativeClustering(n_clusters=k)
# Out:
# CPU times: user 10.2 s, sys: 821 ms, total: 11 s
# Wall time: 8.97 s

# %%
sample = np.random.choice(len(svd), replace=False, size=8000)
# %time agg_sample = agg.fit_predict(svd[sample])
# Out:
# CPU times: user 11.7 s, sys: 433 ms, total: 12.2 s
# Wall time: 12.4 s

# %%
# let's get the centroid/average of each cluster
centroids = np.array([svd[sample][agg_sample == c].mean(axis=0) for c in range(k)])
# initialize k-means with the agglomerative clusters
km = KMeans(n_clusters=k, n_jobs=-1, init=centroids)

# %time km.fit(svd)
# Out:
# /anaconda2/envs/python36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:968: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# CPU times: user 2.66 s, sys: 170 ms, total: 2.83 s
# Wall time: 1.55 s
# KMeans(algorithm='auto', copy_x=True,
#     init=array([[ 1.25937e-01, -3.10020e-02, ..., -2.75348e-04,  4.97106e-04],
#        [ 1.37852e-01,  3.86382e-03, ...,  1.06298e-04, -6.08355e-04],
#        ...,
#        [ 1.42283e-01, -1.13223e-02, ...,  2.04565e-04,  3.87622e-03],
#        [ 1.33510e-01,  3.67213e-03, ...,  1.14352e-03, -2.17352e-03]]),
#     max_iter=300, n_clusters=10, n_init=10, n_jobs=-1,
#     precompute_distances='auto', random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## Visualization (9 pts)
#
# Provide visualzations for at least 3 of the analyses above. Be creative. Just please do not use word clouds...

# %% [markdown]
# ### Tfidf visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)

# %%
df2.head()
# Out:
#            word  tf       idf  tfidf
# 4654   injuries  25  7.868575    0.0
# 5497   majestic  26  7.830834    0.0
# 6951  privilege  26  7.830834    0.0
# 1203     busted  27  7.794467    0.0
# 6350  outbursts  27  7.794467    0.0

# %%
sns.distplot(df2['tfidf'])

# %% [markdown]
# ##### The distribution of the importance of the words are right-skewed, which means the majority of words in corpus are not good classifiers to differentiate the documents.
# ##### And this finding is predictable according to the Zipf's law.

# %% [markdown]
# ### Latent topics with LDA visualization

# %%
# get a list of all the topic scores for each document
scores = [[t[1] for t in topic_corpus[entry]] for entry in range(25000)]

# turn that into a data frame with N rows and K columns, each with the score of the corresponding topic
topic_distros = pd.DataFrame(data=scores, columns=descriptors)

# add the review attitude of each document (so we can aggregate)
topic_distros['attitude'] = df.attitude[:25000]

# %%
topic_distros.head()
# Out:
#    freddy, murphy  jesus, eddie  horror, worst  hitler, germany  \
# 0        0.022691      0.022674       0.022684         0.022674
# 1        0.013384      0.013384       0.013388         0.013384
# 2        0.027007      0.027005       0.027010         0.027005
# 3        0.010781      0.010779       0.010782         0.010779
# 4        0.014284      0.014284       0.014288         0.014284
#
#    worst, stupid  stanley, inspiring  bugs, deeper  christmas, santa  \
# 0       0.022683            0.022674      0.022674          0.022674
# 1       0.013388            0.013385      0.013384          0.013384
# 2       0.027016            0.027005      0.027005          0.027005
# 3       0.185049            0.010779      0.010779          0.010779
# 4       0.441091            0.014284      0.014284          0.014284
#
#    season, trek  role, performance  attitude
# 0      0.022674           0.795897  positive
# 1      0.013386           0.879532  positive
# 2      0.027006           0.756935  positive
# 3      0.010780           0.728711  positive
# 4      0.014289           0.444627  positive

# %%
# %matplotlib inline
import matplotlib.pyplot as plt # make graphs
import seaborn # make prettier graphs

seaborn.set_context('poster') # use large font

fig, ax = plt.subplots(figsize=(10, 5)) # set graph size
# aggregate topics by review categories
aggregate_by_attitude = topic_distros.groupby(topic_distros.attitude).mean()
# plot the graph
aggregate_by_attitude[descriptors].plot.bar(ax=ax);
# move the legend out
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# ##### As is inferred from this barplot, most of the latent topics seems of low frequency.
# ##### However, those related to the performance of the actors/actresses and the genres of the films are important influencing factors of the reviewers' attitudes.
# ##### The audience are most likely to talk about the casts and their direct feelings, instead of substantial contents of the films, such as the scenarios and characters.

# %% [markdown]
# ### Topic modeling with LDA visualization

# %%
from sklearn.decomposition import LatentDirichletAllocation
n_topics=3 #num of topics adjusted after plotting
lda = LatentDirichletAllocation(n_components=n_topics, max_iter=50,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(X2)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=50, mean_change_tol=0.001,
#              n_components=3, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=0, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# We use intertopic distance map to capture the most frequent terms of each topic.
# This is supposed to be an interactive map. Please rerun if it doesn't show up or use the html link in the file folder.
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
vis = pyLDAvis.sklearn.prepare(lda, X2, vectorizer)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.124914  0.074860       1        1  37.856360
# 1      0.023254 -0.119255       2        1  34.945526
# 2     -0.148169  0.044395       3        1  27.198114, topic_info=      Category         Freq         Term        Total  loglift  logprob
# term
# 4502   Default  4758.000000           im  4758.000000  30.0000  30.0000
# 10061  Default  2751.000000        worst  2751.000000  29.0000  29.0000
# 5512   Default  5198.000000          man  5198.000000  28.0000  28.0000
# 9852   Default  4437.000000     watching  4437.000000  27.0000  27.0000
# 3724   Default  3978.000000        funny  3978.000000  26.0000  26.0000
# 7840   Default  5261.000000          say  5261.000000  25.0000  25.0000
# 9813   Default  1830.000000          war  1830.000000  24.0000  24.0000
# 9955   Default  1962.000000         wife  1962.000000  23.0000  23.0000
# 10125  Default  3560.000000        young  3560.000000  22.0000  22.0000
# 4909   Default  2112.000000         john  2112.000000  21.0000  21.0000
# 8777   Default  1647.000000       stupid  1647.000000  20.0000  20.0000
# 6713   Default  2192.000000        plays  2192.000000  19.0000  19.0000
# 659    Default  1630.000000        awful  1630.000000  18.0000  18.0000
# 7672   Default  3059.000000         role  3059.000000  17.0000  17.0000
# 4383   Default  3260.000000       horror  3260.000000  16.0000  16.0000
# 9144   Default  4354.000000        thing  4354.000000  15.0000  15.0000
# 9843   Default  1498.000000        waste  1498.000000  14.0000  14.0000
# 4836   Default  3288.000000          ive  3288.000000  13.0000  13.0000
# 9301   Default  1170.000000         town  1170.000000  12.0000  12.0000
# 6917   Default  3590.000000       pretty  3590.000000  11.0000  11.0000
# 9090   Default  1624.000000     terrible  1624.000000  10.0000  10.0000
# 3833   Default  3202.000000         gets  3202.000000   9.0000   9.0000
# 4250   Default  2891.000000          hes  2891.000000   8.0000   8.0000
# 9159   Default  3231.000000      thought  3231.000000   7.0000   7.0000
# 10048  Default  3417.000000        world  3417.000000   6.0000   6.0000
# 4399   Default  2030.000000        house  2030.000000   5.0000   5.0000
# 5953   Default  1002.000000       murder  1002.000000   4.0000   4.0000
# 10017  Default  2593.000000        woman  2593.000000   3.0000   3.0000
# 4061   Default  2851.000000          guy  2851.000000   2.0000   2.0000
# 1018   Default  1751.000000       boring  1751.000000   1.0000   1.0000
# ...        ...          ...          ...          ...      ...      ...
# 5512    Topic3  3236.246312          man  5198.368738   0.8281  -5.1082
# 6525    Topic3   693.473927         paul   827.252521   1.1256  -6.6486
# 10017   Topic3  1774.649295        woman  2593.751446   0.9225  -5.7090
# 5735    Topic3   950.737829      michael  1246.336501   1.0313  -6.3331
# 7672    Topic3  1921.902530         role  3059.029510   0.8372  -5.6292
# 4399    Topic3  1388.493437        house  2030.581922   0.9219  -5.9543
# 4250    Topic3  1818.945329          hes  2891.330422   0.8386  -5.6843
# 2251    Topic3   803.333418     daughter  1015.273826   1.0679  -6.5015
# 6004    Topic3   653.611401        named   784.598663   1.1194  -6.7078
# 3833    Topic3  1853.020234         gets  3202.964988   0.7548  -5.6657
# 3376    Topic3  1170.342000       father  1789.304975   0.8775  -6.1253
# 10125   Topic3  1862.846625        young  3560.779553   0.6541  -5.6605
# 6708    Topic3  1444.196965       played  2519.738723   0.7454  -5.9150
# 9436    Topic3   887.625917        turns  1242.619563   0.9656  -6.4018
# 7591    Topic3   672.156111      richard   836.272125   1.0836  -6.6798
# 5134    Topic3  1162.400823        later  2090.639077   0.7150  -6.1321
# 1344    Topic3  1595.317027         cast  3645.934200   0.4755  -5.8155
# 3908    Topic3  1247.588359         goes  2401.797379   0.6470  -6.0614
# 3861    Topic3  1206.691356         girl  2566.354996   0.5474  -6.0947
# 7865    Topic3  1682.600661        scene  5149.233007   0.1835  -5.7622
# 6573    Topic3  1231.248963  performance  2787.174222   0.4850  -6.0745
# 6257    Topic3  1401.737223          old  3987.171634   0.2567  -5.9449
# 8989    Topic3  1025.688161        takes  2147.793995   0.5629  -6.2572
# 6075    Topic3  1282.188706          new  4198.141449   0.1159  -6.0340
# 1736    Topic3  1057.214481        comes  2463.218792   0.4562  -6.2269
# 3334    Topic3  1113.061455       family  2944.814979   0.3291  -6.1755
# 6095    Topic3   936.636976        night  2012.528369   0.5372  -6.3480
# 2991    Topic3  1038.583650          end  5331.467034  -0.3337  -6.2447
# 9137    Topic3   960.725937       theres  3091.061580   0.1334  -6.3226
# 5249    Topic3   976.895428         life  5895.096784  -0.4955  -6.3059
#
# [281 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 87         1  0.007186    accurate
# 87         2  0.991687    accurate
# 115        1  0.565893      actors
# 115        2  0.389868      actors
# 115        3  0.044235      actors
# 123        1  0.729538    actually
# 123        2  0.196913    actually
# 123        3  0.073482    actually
# 128        2  0.998203  adaptation
# 283        3  0.998432       allen
# 327        1  0.162837    american
# 327        2  0.691066    american
# 327        3  0.146454    american
# 328        1  0.020356   americans
# 328        2  0.977083   americans
# 390        1  0.989088    annoying
# 390        2  0.006093    annoying
# 390        3  0.005077    annoying
# 425        2  0.012851   apartment
# 425        3  0.986339   apartment
# 513        1  0.128126         art
# 513        2  0.870372         art
# 513        3  0.001767         art
# 522        1  0.005928    artistic
# 522        2  0.992971    artistic
# 612        1  0.343687    audience
# 612        2  0.616687    audience
# 612        3  0.039487    audience
# 659        1  0.999240       awful
# 719        3  0.998328        bank
# ...      ...       ...         ...
# 9955       3  0.861337        wife
# 9963       2  0.044334     william
# 9963       3  0.954072     william
# 10017      1  0.101398       woman
# 10017      2  0.214361       woman
# 10017      3  0.684337       woman
# 10025      1  0.035601   wonderful
# 10025      2  0.727918   wonderful
# 10025      3  0.236494   wonderful
# 10041      1  0.293495        work
# 10041      2  0.513923        work
# 10041      3  0.192383        work
# 10048      1  0.150711       world
# 10048      2  0.786918       world
# 10048      3  0.062333       world
# 10058      1  0.929341       worse
# 10058      2  0.042147       worse
# 10058      3  0.028800       worse
# 10061      1  0.990636       worst
# 10061      2  0.009085       worst
# 10061      3  0.000363       worst
# 10106      1  0.998209        yeah
# 10111      1  0.304148       years
# 10111      2  0.499314       years
# 10111      3  0.196534       years
# 10125      1  0.012357       young
# 10125      2  0.464505       young
# 10125      3  0.523200       young
# 10140      1  0.964265      zombie
# 10140      3  0.035278      zombie
#
# [497 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])

# %%
pyLDAvis.save_html(vis, 'lda.html')

# %% [markdown]
# As can be referred from the most frequent terms of each cluster, the 3 latent topics roughly could be:
# - negative comments (Topic 1);
# - positive comments (Topic 2);
# - discriptive comments with no obvious attitudes (Topic 3).

# %% [markdown]
# ### Dense word embeddings visualization

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline


def tsne_plot(model, title):
    "Creates an TSNE model and plots it"
    labels = []
    tokens = []
    

    for word in model.wv.index2word:
        tokens.append(model[word])
        labels.append(word)
    
    
    # fit the model into 2 dimensions(n_components=2)
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
    
    
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    
    plt.title("Word embedding visualization of {}".format(title),fontsize=24)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
tsne_plot(model_pos, "positive reviews")

# %%
tsne_plot(model_neg, "negative reviews")

# %% [markdown]
# ### Clustering visualization

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import colors
import seaborn as sb

sb.set_context('poster')


def plot_vectors(vectors, title='Clustering visualization', labels=None, dimensions=3):
    """
    plot the vectors in 2 or 3 dimensions. If supplied, color them according to the labels
    """
    # set up graph
    fig = plt.figure(figsize=(10,10))

    # create data frame
    df = pd.DataFrame(data={'x':vectors[:,0], 'y': vectors[:,1]})
    # add labels, if supplied
    if labels is not None:
        df['label'] = labels
    else:
        df['label'] = [''] * len(df)

    # assign colors to labels
    cm = plt.get_cmap('tab20b') # choose the color palette
    n_labels = len(df.label.unique())
    label_colors = [cm(1. * i/n_labels) for i in range(n_labels)]
    cMap = colors.ListedColormap(label_colors)
        
    # plot in 3 dimensions
    if dimensions == 3:
        # add z-axis information
        df['z'] = vectors[:,2]
        # define plot
        ax = fig.add_subplot(111, projection='3d')
        frame1 = plt.gca() 
        # remove axis ticks
        frame1.axes.xaxis.set_ticklabels([])
        frame1.axes.yaxis.set_ticklabels([])
        frame1.axes.zaxis.set_ticklabels([])

        # plot each label as scatter plot in its own color
        for l, label in enumerate(df.label.unique()):
            df2 = df[df.label == label]
            ax.scatter(df2['x'], df2['y'], df2['z'], c=label_colors[l], cmap=cMap, edgecolor=None, label=label, alpha=0.3, s=100)
      
    # plot in 2 dimensions
    elif dimensions == 2:
        ax = fig.add_subplot(111)
        frame1 = plt.gca() 
        frame1.axes.xaxis.set_ticklabels([])
        frame1.axes.yaxis.set_ticklabels([])

        for l, label in enumerate(df.label.unique()):
            df2 = df[df.label == label]
            ax.scatter(df2['x'], df2['y'], c=label_colors[l], cmap=cMap, edgecolor=None, label=label, alpha=0.3, s=100)

    else:
        raise NotImplementedError()

    plt.title(title)
    plt.show()

# %%
#clustering
svd = TruncatedSVD(n_components=300).fit_transform(X)

plot_sample = np.random.choice(len(svd), replace=False, size=500)
plot_vectors(svd[plot_sample], labels=km.labels_[plot_sample])

# %% [markdown]
# ##### It's comparatively obvious to see the brown cluster, the violet cluster and the green cluster.

# %%
sample = np.random.choice(len(svd), replace=False, size=8000)#change size to 8000
plot_vectors(svd[sample[:500]], labels=agg_sample[:500])

# %% [markdown]
# ##### Conclusion:
# In this project I only performed analysis using the training set, and based my analysis on the provided attitude tag("positive" or "negative") of the reviews. To dig deeper into the dataset in the final project, I will focus more on the 50,000 unsupervised reviews, split the training and the test set, do sentimental analysis classifying the attitude and fit the model into the test set. I will assess and further improve the accuracy of the prediction model.
